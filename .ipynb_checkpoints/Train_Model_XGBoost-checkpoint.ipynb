# %%
# !pip install sagemaker==1.72.0

# %%
## Import relevant libraries
import os
import boto3
import re
import sagemaker
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import io
import time
import json
import sagemaker.amazon.common as smac
import scipy
from sklearn.model_selection import train_test_split
from sagemaker.amazon.amazon_estimator import get_image_uri

## Defin role, region, session, and default s3 bucket ##
role = sagemaker.get_execution_role()
region = boto3.Session().region_name
session = sagemaker.Session()
bucket = session.default_bucket()

# %%
## Read in processed datasets ##
X_sparse = scipy.sparse.load_npz('./readmissions_X.npz')
y_sparse = scipy.sparse.load_npz('./readmissions_y.npz')
X = pd.DataFrame(np.array(X_sparse.todense()))
y = pd.DataFrame(np.array(y_sparse.todense()).reshape(-1,1))

# %%
## Create train/test/validation sets ##
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.33)

# %% [markdown]
# #### Build XGboost Classifier

# %%
prefix = 'readmission-xgboost'
data_dir = './data/'
if not os.path.exists(data_dir):
    os.makedirs(data_dir)

## Save train/test/validation sets to local data directory ##
pd.DataFrame(X_test).to_csv(os.path.join(data_dir, 'test.csv'), header=False, index=False)
pd.concat([y_val, X_val], axis=1).to_csv(os.path.join(data_dir, 'validation.csv'), header=False, index=False)
pd.concat([y_train, X_train], axis=1).to_csv(os.path.join(data_dir, 'train.csv'), header=False, index=False)

## Upload train/test/validation sets from local directory to s3 bucket ##
test_location = session.upload_data(os.path.join(data_dir, 'test.csv'), key_prefix=prefix)
val_location = session.upload_data(os.path.join(data_dir, 'validation.csv'), key_prefix=prefix)
train_location = session.upload_data(os.path.join(data_dir, 'train.csv'), key_prefix=prefix)

# %%
## Define estimator object
from sagemaker.tuner import IntegerParameter, ContinuousParameter, HyperparameterTuner
container = get_image_uri(session.boto_region_name, 'xgboost')
xgb = sagemaker.estimator.Estimator(container, 
                                    role,                                   
                                    train_instance_count=1,                 
                                    train_instance_type='ml.m4.xlarge',    
                                    output_path='s3://{}/{}/output'.format(bucket, prefix),
                                    sagemaker_session=session)
# Out:
# 'get_image_uri' method will be deprecated in favor of 'ImageURIProvider' class in SageMaker Python SDK v2.
# There is a more up to date SageMaker XGBoost image. To use the newer image, please set 'repo_version'='1.0-1'. For example:
# 	get_image_uri(region, 'xgboost', '1.0-1').
# Parameter image_name will be renamed to image_uri in SageMaker Python SDK v2.

# %%
## Define default and tunable hyperparameters ## 
xgb.set_hyperparameters(silent=0,
                        objective='binary:logistic',
                        early_stopping_rounds=10,
                        num_round=500)

xgb_hyperparameter_tuner = HyperparameterTuner(estimator = xgb, 
                                               objective_metric_name = 'validation:auc', 
                                               objective_type = 'Maximize',
                                               max_jobs = 20,
                                               max_parallel_jobs = 3,
                                               hyperparameter_ranges = {
                                                    'max_depth': IntegerParameter(3, 12),
                                                    'eta'      : ContinuousParameter(0.05, 0.5),
                                                    'min_child_weight': IntegerParameter(2, 8),
                                                    'subsample': ContinuousParameter(0.5, 0.9),
                                                    'gamma': ContinuousParameter(0, 10)})

# %%
## Point hyperparameter tuner object to training/validation data in s3 ##
s3_input_train = sagemaker.s3_input(s3_data=train_location, content_type='csv')
s3_input_validation = sagemaker.s3_input(s3_data=val_location, content_type='csv')
# Out:
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.

# %%
## Fit hyperparameter tuner object ##
xgb_hyperparameter_tuner.fit({'train': s3_input_train, 'validation': s3_input_validation})
xgb_hyperparameter_tuner.wait()
# Out:
# .......................................................................................................................................................................................................................................................................................................................................................................................................................................................................................!

# %%
## View Hyperparameters and performance for best job ##
analytics = xgb_hyperparameter_tuner.analytics()
analytics_df = analytics.dataframe()

best_job = xgb_hyperparameter_tuner.best_training_job()
analytics_df[analytics_df['TrainingJobName'] == best_job]
# Out:
#         eta     gamma  max_depth  min_child_weight  subsample  \
# 0  0.052606  0.698577       12.0               4.0   0.890847
#
#                     TrainingJobName TrainingJobStatus  FinalObjectiveValue  \
# 0  xgboost-220104-1801-020-557217e0         Completed             0.737531
#
#           TrainingStartTime           TrainingEndTime  \
# 0 2022-01-04 18:37:34+00:00 2022-01-04 18:40:22+00:00
#
#    TrainingElapsedTimeSeconds
# 0                       168.0

# %%
## Create a new estimator object using the "best training job" ##
xgb_best = sagemaker.estimator.Estimator.attach(xgb_hyperparameter_tuner.best_training_job())

## Create a batch transform job and point to s3 training data location ##
xgb_transformer = xgb_best.transformer(instance_count = 1, instance_type = 'ml.m4.xlarge')
xgb_transformer.transform(test_location, content_type='text/csv', split_type='Line')
xgb_transformer.wait()
# Out:
# Parameter image_name will be renamed to image_uri in SageMaker Python SDK v2.
# 2022-01-04 18:40:22 Starting - Preparing the instances for training
# 2022-01-04 18:40:22 Downloading - Downloading input data
# 2022-01-04 18:40:22 Training - Training image download completed. Training in progress.
# 2022-01-04 18:40:22 Uploading - Uploading generated training model
# 2022-01-04 18:40:22 Completed - Training job completedArguments: train
# [2022-01-04:18:38:28:INFO] Running standalone xgboost training.
# [2022-01-04:18:38:28:INFO] Setting up HPO optimized metric to be : auc
# [2022-01-04:18:38:28:INFO] File size need to be processed in the node: 12.79mb. Available memory size in the node: 8382.16mb
# [2022-01-04:18:38:28:INFO] Determined delimiter of CSV input is ','
# [18:38:28] S3DistributionType set as FullyReplicated
# [18:38:28] 42031x105 matrix with 4413255 entries loaded from /opt/ml/input/data/train?format=csv&label_column=0&delimiter=,
# [2022-01-04:18:38:28:INFO] Determined delimiter of CSV input is ','
# [18:38:28] S3DistributionType set as FullyReplicated
# [18:38:28] 20702x105 matrix with 2173710 entries loaded from /opt/ml/input/data/validation?format=csv&label_column=0&delimiter=,
# [18:38:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 926 extra nodes, 38 pruned nodes, max_depth=12
# [0]#011train-auc:0.71406#011validation-auc:0.654017
# Multiple eval metrics have been passed: 'validation-auc' will be used for early stopping.
# Will train until validation-auc hasn't improved in 10 rounds.
# [18:38:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 900 extra nodes, 54 pruned nodes, max_depth=12
# [1]#011train-auc:0.735273#011validation-auc:0.67192
# [18:38:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 934 extra nodes, 70 pruned nodes, max_depth=12
# [2]#011train-auc:0.743551#011validation-auc:0.677082
# [18:38:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 910 extra nodes, 28 pruned nodes, max_depth=12
# [3]#011train-auc:0.749061#011validation-auc:0.678323
# [18:38:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 938 extra nodes, 62 pruned nodes, max_depth=12
# [4]#011train-auc:0.752457#011validation-auc:0.681047
# [18:38:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 870 extra nodes, 50 pruned nodes, max_depth=12
# [5]#011train-auc:0.754711#011validation-auc:0.682253
# [18:38:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 904 extra nodes, 40 pruned nodes, max_depth=12
# [6]#011train-auc:0.75685#011validation-auc:0.683403
# [18:38:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 904 extra nodes, 60 pruned nodes, max_depth=12
# [7]#011train-auc:0.758547#011validation-auc:0.683616
# [18:38:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 954 extra nodes, 48 pruned nodes, max_depth=12
# [8]#011train-auc:0.760227#011validation-auc:0.683985
# [18:38:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 840 extra nodes, 28 pruned nodes, max_depth=12
# [9]#011train-auc:0.761529#011validation-auc:0.684208
# [18:38:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 948 extra nodes, 46 pruned nodes, max_depth=12
# [10]#011train-auc:0.764794#011validation-auc:0.685739
# [18:38:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 804 extra nodes, 46 pruned nodes, max_depth=12
# [11]#011train-auc:0.76659#011validation-auc:0.686973
# [18:38:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 682 extra nodes, 60 pruned nodes, max_depth=12
# [12]#011train-auc:0.767599#011validation-auc:0.687465
# [18:38:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 826 extra nodes, 44 pruned nodes, max_depth=12
# [13]#011train-auc:0.769734#011validation-auc:0.688388
# [18:38:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 750 extra nodes, 32 pruned nodes, max_depth=12
# [14]#011train-auc:0.770799#011validation-auc:0.689737
# [18:38:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 838 extra nodes, 48 pruned nodes, max_depth=12
# [15]#011train-auc:0.772585#011validation-auc:0.690025
# [18:38:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 758 extra nodes, 34 pruned nodes, max_depth=12
# [16]#011train-auc:0.774072#011validation-auc:0.690521
# [18:38:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 770 extra nodes, 42 pruned nodes, max_depth=12
# [17]#011train-auc:0.775575#011validation-auc:0.69093
# [18:38:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 954 extra nodes, 36 pruned nodes, max_depth=12
# [18]#011train-auc:0.778954#011validation-auc:0.692304
# [18:38:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 710 extra nodes, 40 pruned nodes, max_depth=12
# [19]#011train-auc:0.779732#011validation-auc:0.692776
# [18:38:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 750 extra nodes, 42 pruned nodes, max_depth=12
# [20]#011train-auc:0.781656#011validation-auc:0.693219
# [18:38:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 672 extra nodes, 32 pruned nodes, max_depth=12
# [21]#011train-auc:0.782623#011validation-auc:0.69362
# [18:38:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 748 extra nodes, 30 pruned nodes, max_depth=12
# [22]#011train-auc:0.784625#011validation-auc:0.694024
# [18:38:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 766 extra nodes, 32 pruned nodes, max_depth=12
# [23]#011train-auc:0.786812#011validation-auc:0.694369
# [18:38:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 730 extra nodes, 50 pruned nodes, max_depth=12
# [24]#011train-auc:0.788419#011validation-auc:0.694835
# [18:38:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 678 extra nodes, 32 pruned nodes, max_depth=12
# [25]#011train-auc:0.789214#011validation-auc:0.695033
# [18:38:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 722 extra nodes, 34 pruned nodes, max_depth=12
# [26]#011train-auc:0.790886#011validation-auc:0.69579
# [18:38:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 634 extra nodes, 48 pruned nodes, max_depth=12
# [27]#011train-auc:0.791719#011validation-auc:0.696085
# [18:38:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 670 extra nodes, 34 pruned nodes, max_depth=12
# [28]#011train-auc:0.792901#011validation-auc:0.696503
# [18:38:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 570 extra nodes, 30 pruned nodes, max_depth=12
# [29]#011train-auc:0.793926#011validation-auc:0.696855
# [18:38:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 620 extra nodes, 34 pruned nodes, max_depth=12
# [30]#011train-auc:0.794801#011validation-auc:0.697136
# [18:38:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 540 extra nodes, 42 pruned nodes, max_depth=12
# [31]#011train-auc:0.795748#011validation-auc:0.697495
# [18:38:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 564 extra nodes, 38 pruned nodes, max_depth=12
# [32]#011train-auc:0.796966#011validation-auc:0.697924
# [18:38:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 612 extra nodes, 36 pruned nodes, max_depth=12
# [33]#011train-auc:0.797975#011validation-auc:0.698304
# [18:38:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 542 extra nodes, 30 pruned nodes, max_depth=12
# [34]#011train-auc:0.799149#011validation-auc:0.698602
# [18:38:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 624 extra nodes, 36 pruned nodes, max_depth=12
# [35]#011train-auc:0.80097#011validation-auc:0.698981
# [18:38:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 604 extra nodes, 42 pruned nodes, max_depth=12
# [36]#011train-auc:0.802271#011validation-auc:0.699338
# [18:38:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 634 extra nodes, 30 pruned nodes, max_depth=12
# [37]#011train-auc:0.803503#011validation-auc:0.699537
# [18:38:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 508 extra nodes, 28 pruned nodes, max_depth=12
# [38]#011train-auc:0.804387#011validation-auc:0.699901
# [18:38:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 626 extra nodes, 32 pruned nodes, max_depth=12
# [39]#011train-auc:0.806091#011validation-auc:0.700293
# [18:38:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 540 extra nodes, 36 pruned nodes, max_depth=12
# [40]#011train-auc:0.807203#011validation-auc:0.700538
# [18:38:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 438 extra nodes, 16 pruned nodes, max_depth=12
# [41]#011train-auc:0.807906#011validation-auc:0.70092
# [18:38:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 522 extra nodes, 50 pruned nodes, max_depth=12
# [42]#011train-auc:0.809091#011validation-auc:0.701197
# [18:38:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 614 extra nodes, 32 pruned nodes, max_depth=12
# [43]#011train-auc:0.810653#011validation-auc:0.701709
# [18:38:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 514 extra nodes, 34 pruned nodes, max_depth=12
# [44]#011train-auc:0.812027#011validation-auc:0.702014
# [18:38:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 536 extra nodes, 34 pruned nodes, max_depth=12
# [45]#011train-auc:0.813087#011validation-auc:0.7023
# [18:38:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 472 extra nodes, 20 pruned nodes, max_depth=12
# [46]#011train-auc:0.814122#011validation-auc:0.702751
# [18:38:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 634 extra nodes, 44 pruned nodes, max_depth=12
# [47]#011train-auc:0.815589#011validation-auc:0.703081
# [18:38:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 494 extra nodes, 36 pruned nodes, max_depth=12
# [48]#011train-auc:0.816528#011validation-auc:0.703478
# [18:38:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 442 extra nodes, 20 pruned nodes, max_depth=12
# [49]#011train-auc:0.817465#011validation-auc:0.703699
# [18:38:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 562 extra nodes, 38 pruned nodes, max_depth=12
# [50]#011train-auc:0.818877#011validation-auc:0.703954
# [18:38:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 510 extra nodes, 36 pruned nodes, max_depth=12
# [51]#011train-auc:0.820016#011validation-auc:0.704424
# [18:38:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 520 extra nodes, 26 pruned nodes, max_depth=12
# [52]#011train-auc:0.821196#011validation-auc:0.704502
# [18:38:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 514 extra nodes, 28 pruned nodes, max_depth=12
# [53]#011train-auc:0.82226#011validation-auc:0.704721
# [18:38:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 368 extra nodes, 48 pruned nodes, max_depth=12
# [54]#011train-auc:0.822967#011validation-auc:0.704893
# [18:38:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 412 extra nodes, 26 pruned nodes, max_depth=12
# [55]#011train-auc:0.823721#011validation-auc:0.705193
# [18:38:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 560 extra nodes, 22 pruned nodes, max_depth=12
# [56]#011train-auc:0.825336#011validation-auc:0.7056
# [18:38:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 280 extra nodes, 12 pruned nodes, max_depth=12
# [57]#011train-auc:0.825768#011validation-auc:0.705857
# [18:38:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 406 extra nodes, 30 pruned nodes, max_depth=12
# [58]#011train-auc:0.826575#011validation-auc:0.706164
# [18:38:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 340 extra nodes, 16 pruned nodes, max_depth=12
# [59]#011train-auc:0.827235#011validation-auc:0.706497
# [18:38:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 334 extra nodes, 26 pruned nodes, max_depth=12
# [60]#011train-auc:0.827938#011validation-auc:0.706733
# [18:38:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 356 extra nodes, 16 pruned nodes, max_depth=12
# [61]#011train-auc:0.828717#011validation-auc:0.70693
# [18:38:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 308 extra nodes, 18 pruned nodes, max_depth=12
# [62]#011train-auc:0.829338#011validation-auc:0.707235
# [18:38:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 406 extra nodes, 14 pruned nodes, max_depth=12
# [63]#011train-auc:0.830394#011validation-auc:0.707479
# [18:38:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 522 extra nodes, 24 pruned nodes, max_depth=12
# [64]#011train-auc:0.831865#011validation-auc:0.707733
# [18:38:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 386 extra nodes, 30 pruned nodes, max_depth=12
# [65]#011train-auc:0.832422#011validation-auc:0.707796
# [18:38:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 402 extra nodes, 22 pruned nodes, max_depth=12
# [66]#011train-auc:0.833224#011validation-auc:0.708012
# [18:38:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 260 extra nodes, 20 pruned nodes, max_depth=12
# [67]#011train-auc:0.833619#011validation-auc:0.708211
# [18:38:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 342 extra nodes, 22 pruned nodes, max_depth=12
# [68]#011train-auc:0.834303#011validation-auc:0.708287
# [18:38:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 458 extra nodes, 24 pruned nodes, max_depth=12
# [69]#011train-auc:0.835549#011validation-auc:0.708664
# [18:38:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 330 extra nodes, 16 pruned nodes, max_depth=12
# [70]#011train-auc:0.836166#011validation-auc:0.708857
# [18:38:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 482 extra nodes, 32 pruned nodes, max_depth=12
# [71]#011train-auc:0.837263#011validation-auc:0.709304
# [18:38:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 192 extra nodes, 4 pruned nodes, max_depth=12
# [72]#011train-auc:0.837515#011validation-auc:0.709526
# [18:38:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 408 extra nodes, 10 pruned nodes, max_depth=12
# [73]#011train-auc:0.838447#011validation-auc:0.709682
# [18:38:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 334 extra nodes, 26 pruned nodes, max_depth=12
# [74]#011train-auc:0.839088#011validation-auc:0.709934
# [18:38:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 324 extra nodes, 18 pruned nodes, max_depth=12
# [75]#011train-auc:0.83967#011validation-auc:0.710142
# [18:38:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 414 extra nodes, 16 pruned nodes, max_depth=12
# [76]#011train-auc:0.84074#011validation-auc:0.710557
# [18:38:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 298 extra nodes, 16 pruned nodes, max_depth=12
# [77]#011train-auc:0.841196#011validation-auc:0.710635
# [18:38:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 240 extra nodes, 26 pruned nodes, max_depth=12
# [78]#011train-auc:0.84161#011validation-auc:0.710765
# [18:38:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 360 extra nodes, 20 pruned nodes, max_depth=12
# [79]#011train-auc:0.84216#011validation-auc:0.71089
# [18:38:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 482 extra nodes, 28 pruned nodes, max_depth=12
# [80]#011train-auc:0.843284#011validation-auc:0.711164
# [18:38:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 418 extra nodes, 24 pruned nodes, max_depth=12
# [81]#011train-auc:0.844295#011validation-auc:0.711287
# [18:38:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 460 extra nodes, 32 pruned nodes, max_depth=12
# [82]#011train-auc:0.845337#011validation-auc:0.711561
# [18:38:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 252 extra nodes, 8 pruned nodes, max_depth=12
# [83]#011train-auc:0.845856#011validation-auc:0.711785
# [18:38:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 448 extra nodes, 22 pruned nodes, max_depth=12
# [84]#011train-auc:0.847028#011validation-auc:0.712089
# [18:38:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 344 extra nodes, 22 pruned nodes, max_depth=12
# [85]#011train-auc:0.847571#011validation-auc:0.712188
# [18:38:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 384 extra nodes, 20 pruned nodes, max_depth=12
# [86]#011train-auc:0.848368#011validation-auc:0.71233
# [18:38:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 256 extra nodes, 8 pruned nodes, max_depth=12
# [87]#011train-auc:0.848734#011validation-auc:0.712494
# [18:38:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 500 extra nodes, 22 pruned nodes, max_depth=12
# [88]#011train-auc:0.850146#011validation-auc:0.712882
# [18:38:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 286 extra nodes, 22 pruned nodes, max_depth=12
# [89]#011train-auc:0.850613#011validation-auc:0.713083
# [18:38:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 280 extra nodes, 16 pruned nodes, max_depth=12
# [90]#011train-auc:0.851101#011validation-auc:0.713174
# [18:38:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 306 extra nodes, 12 pruned nodes, max_depth=12
# [91]#011train-auc:0.851586#011validation-auc:0.71333
# [18:38:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 496 extra nodes, 16 pruned nodes, max_depth=12
# [92]#011train-auc:0.852832#011validation-auc:0.71356
# [18:38:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 306 extra nodes, 24 pruned nodes, max_depth=12
# [93]#011train-auc:0.85332#011validation-auc:0.713608
# [18:38:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 422 extra nodes, 6 pruned nodes, max_depth=12
# [94]#011train-auc:0.854322#011validation-auc:0.713837
# [18:38:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 382 extra nodes, 16 pruned nodes, max_depth=12
# [95]#011train-auc:0.855282#011validation-auc:0.714137
# [18:38:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 380 extra nodes, 22 pruned nodes, max_depth=12
# [96]#011train-auc:0.856034#011validation-auc:0.714268
# [18:38:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 456 extra nodes, 26 pruned nodes, max_depth=12
# [97]#011train-auc:0.85685#011validation-auc:0.714427
# [18:38:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 322 extra nodes, 32 pruned nodes, max_depth=12
# [98]#011train-auc:0.857616#011validation-auc:0.714647
# [18:38:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 314 extra nodes, 16 pruned nodes, max_depth=12
# [99]#011train-auc:0.858273#011validation-auc:0.71475
# [18:38:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 274 extra nodes, 16 pruned nodes, max_depth=12
# [100]#011train-auc:0.858867#011validation-auc:0.714867
# [18:38:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 228 extra nodes, 16 pruned nodes, max_depth=12
# [101]#011train-auc:0.859313#011validation-auc:0.714938
# [18:38:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 348 extra nodes, 28 pruned nodes, max_depth=12
# [102]#011train-auc:0.860131#011validation-auc:0.715069
# [18:38:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 272 extra nodes, 12 pruned nodes, max_depth=12
# [103]#011train-auc:0.86049#011validation-auc:0.715186
# [18:38:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 590 extra nodes, 46 pruned nodes, max_depth=12
# [104]#011train-auc:0.861845#011validation-auc:0.715455
# [18:38:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 452 extra nodes, 10 pruned nodes, max_depth=12
# [105]#011train-auc:0.862806#011validation-auc:0.715613
# [18:38:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 288 extra nodes, 12 pruned nodes, max_depth=12
# [106]#011train-auc:0.863211#011validation-auc:0.715765
# [18:38:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 338 extra nodes, 28 pruned nodes, max_depth=12
# [107]#011train-auc:0.864092#011validation-auc:0.715974
# [18:38:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 328 extra nodes, 20 pruned nodes, max_depth=12
# [108]#011train-auc:0.864779#011validation-auc:0.716234
# [18:38:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 208 extra nodes, 10 pruned nodes, max_depth=12
# [109]#011train-auc:0.865169#011validation-auc:0.716154
# [18:38:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 420 extra nodes, 30 pruned nodes, max_depth=12
# [110]#011train-auc:0.866015#011validation-auc:0.71634
# [18:38:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 346 extra nodes, 14 pruned nodes, max_depth=12
# [111]#011train-auc:0.866633#011validation-auc:0.716478
# [18:38:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 456 extra nodes, 42 pruned nodes, max_depth=12
# [112]#011train-auc:0.867454#011validation-auc:0.716655
# [18:38:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 294 extra nodes, 20 pruned nodes, max_depth=12
# [113]#011train-auc:0.868064#011validation-auc:0.716721
# [18:38:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 180 extra nodes, 12 pruned nodes, max_depth=12
# [114]#011train-auc:0.868364#011validation-auc:0.716766
# [18:38:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 378 extra nodes, 28 pruned nodes, max_depth=12
# [115]#011train-auc:0.869118#011validation-auc:0.716895
# [18:38:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 378 extra nodes, 20 pruned nodes, max_depth=12
# [116]#011train-auc:0.869823#011validation-auc:0.717141
# [18:38:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 412 extra nodes, 36 pruned nodes, max_depth=12
# [117]#011train-auc:0.870659#011validation-auc:0.717301
# [18:38:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 532 extra nodes, 30 pruned nodes, max_depth=12
# [118]#011train-auc:0.871684#011validation-auc:0.717643
# [18:38:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 272 extra nodes, 20 pruned nodes, max_depth=12
# [119]#011train-auc:0.872096#011validation-auc:0.717727
# [18:38:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 350 extra nodes, 28 pruned nodes, max_depth=12
# [120]#011train-auc:0.872733#011validation-auc:0.71801
# [18:38:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 252 extra nodes, 30 pruned nodes, max_depth=12
# [121]#011train-auc:0.873198#011validation-auc:0.718095
# [18:38:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 374 extra nodes, 22 pruned nodes, max_depth=12
# [122]#011train-auc:0.873852#011validation-auc:0.718149
# [18:38:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 336 extra nodes, 16 pruned nodes, max_depth=12
# [123]#011train-auc:0.874327#011validation-auc:0.718191
# [18:38:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 240 extra nodes, 12 pruned nodes, max_depth=12
# [124]#011train-auc:0.874608#011validation-auc:0.71823
# [18:38:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 388 extra nodes, 30 pruned nodes, max_depth=12
# [125]#011train-auc:0.875394#011validation-auc:0.71839
# [18:38:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 550 extra nodes, 36 pruned nodes, max_depth=12
# [126]#011train-auc:0.876499#011validation-auc:0.718629
# [18:38:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 400 extra nodes, 22 pruned nodes, max_depth=12
# [127]#011train-auc:0.877359#011validation-auc:0.718765
# [18:38:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 542 extra nodes, 40 pruned nodes, max_depth=12
# [128]#011train-auc:0.878575#011validation-auc:0.719002
# [18:38:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 306 extra nodes, 16 pruned nodes, max_depth=12
# [129]#011train-auc:0.878883#011validation-auc:0.719051
# [18:38:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 226 extra nodes, 6 pruned nodes, max_depth=12
# [130]#011train-auc:0.879192#011validation-auc:0.718996
# [18:38:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 322 extra nodes, 24 pruned nodes, max_depth=12
# [131]#011train-auc:0.879724#011validation-auc:0.719168
# [18:38:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 338 extra nodes, 20 pruned nodes, max_depth=12
# [132]#011train-auc:0.880378#011validation-auc:0.719256
# [18:38:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 300 extra nodes, 10 pruned nodes, max_depth=12
# [133]#011train-auc:0.880786#011validation-auc:0.719365
# [18:38:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 182 extra nodes, 8 pruned nodes, max_depth=12
# [134]#011train-auc:0.881027#011validation-auc:0.719368
# [18:38:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 538 extra nodes, 28 pruned nodes, max_depth=12
# [135]#011train-auc:0.882044#011validation-auc:0.71967
# [18:38:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 308 extra nodes, 30 pruned nodes, max_depth=12
# [136]#011train-auc:0.882527#011validation-auc:0.719728
# [18:38:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 340 extra nodes, 20 pruned nodes, max_depth=12
# [137]#011train-auc:0.883171#011validation-auc:0.719936
# [18:38:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 408 extra nodes, 24 pruned nodes, max_depth=12
# [138]#011train-auc:0.883908#011validation-auc:0.720138
# [18:38:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 382 extra nodes, 10 pruned nodes, max_depth=12
# [139]#011train-auc:0.884573#011validation-auc:0.720212
# [18:38:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 576 extra nodes, 46 pruned nodes, max_depth=12
# [140]#011train-auc:0.885619#011validation-auc:0.720341
# [18:38:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 274 extra nodes, 24 pruned nodes, max_depth=12
# [141]#011train-auc:0.886014#011validation-auc:0.720486
# [18:38:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 554 extra nodes, 46 pruned nodes, max_depth=12
# [142]#011train-auc:0.887129#011validation-auc:0.720572
# [18:38:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 384 extra nodes, 16 pruned nodes, max_depth=12
# [143]#011train-auc:0.887782#011validation-auc:0.720659
# [18:38:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 538 extra nodes, 24 pruned nodes, max_depth=12
# [144]#011train-auc:0.888797#011validation-auc:0.720828
# [18:39:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 218 extra nodes, 4 pruned nodes, max_depth=12
# [145]#011train-auc:0.889074#011validation-auc:0.720889
# [18:39:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 242 extra nodes, 12 pruned nodes, max_depth=12
# [146]#011train-auc:0.889452#011validation-auc:0.720987
# [18:39:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 202 extra nodes, 12 pruned nodes, max_depth=12
# [147]#011train-auc:0.889614#011validation-auc:0.721051
# [18:39:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 418 extra nodes, 26 pruned nodes, max_depth=12
# [148]#011train-auc:0.890406#011validation-auc:0.721005
# [18:39:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 504 extra nodes, 30 pruned nodes, max_depth=12
# [149]#011train-auc:0.891412#011validation-auc:0.721152
# [18:39:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 664 extra nodes, 34 pruned nodes, max_depth=12
# [150]#011train-auc:0.892695#011validation-auc:0.721362
# [18:39:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 446 extra nodes, 22 pruned nodes, max_depth=12
# [151]#011train-auc:0.893462#011validation-auc:0.72149
# [18:39:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 462 extra nodes, 24 pruned nodes, max_depth=12
# [152]#011train-auc:0.894217#011validation-auc:0.721681
# [18:39:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 324 extra nodes, 20 pruned nodes, max_depth=12
# [153]#011train-auc:0.894645#011validation-auc:0.721796
# [18:39:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 168 extra nodes, 4 pruned nodes, max_depth=12
# [154]#011train-auc:0.894841#011validation-auc:0.721858
# [18:39:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 430 extra nodes, 36 pruned nodes, max_depth=12
# [155]#011train-auc:0.895455#011validation-auc:0.722031
# [18:39:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 348 extra nodes, 30 pruned nodes, max_depth=12
# [156]#011train-auc:0.896021#011validation-auc:0.722081
# [18:39:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 424 extra nodes, 20 pruned nodes, max_depth=12
# [157]#011train-auc:0.896616#011validation-auc:0.722244
# [18:39:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 364 extra nodes, 30 pruned nodes, max_depth=12
# [158]#011train-auc:0.897106#011validation-auc:0.722428
# [18:39:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 190 extra nodes, 12 pruned nodes, max_depth=12
# [159]#011train-auc:0.897329#011validation-auc:0.72245
# [18:39:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 600 extra nodes, 40 pruned nodes, max_depth=12
# [160]#011train-auc:0.898317#011validation-auc:0.722559
# [18:39:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 328 extra nodes, 26 pruned nodes, max_depth=12
# [161]#011train-auc:0.898659#011validation-auc:0.722563
# [18:39:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 334 extra nodes, 16 pruned nodes, max_depth=12
# [162]#011train-auc:0.899134#011validation-auc:0.722724
# [18:39:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 186 extra nodes, 24 pruned nodes, max_depth=12
# [163]#011train-auc:0.899304#011validation-auc:0.722803
# [18:39:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 454 extra nodes, 24 pruned nodes, max_depth=12
# [164]#011train-auc:0.900003#011validation-auc:0.722878
# [18:39:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 506 extra nodes, 30 pruned nodes, max_depth=12
# [165]#011train-auc:0.900729#011validation-auc:0.722898
# [18:39:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 320 extra nodes, 30 pruned nodes, max_depth=12
# [166]#011train-auc:0.901114#011validation-auc:0.722971
# [18:39:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 374 extra nodes, 10 pruned nodes, max_depth=12
# [167]#011train-auc:0.901552#011validation-auc:0.722992
# [18:39:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 266 extra nodes, 12 pruned nodes, max_depth=12
# [168]#011train-auc:0.901874#011validation-auc:0.723024
# [18:39:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 442 extra nodes, 38 pruned nodes, max_depth=12
# [169]#011train-auc:0.902467#011validation-auc:0.723057
# [18:39:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 254 extra nodes, 26 pruned nodes, max_depth=12
# [170]#011train-auc:0.902724#011validation-auc:0.723142
# [18:39:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 450 extra nodes, 32 pruned nodes, max_depth=12
# [171]#011train-auc:0.90337#011validation-auc:0.723319
# [18:39:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 254 extra nodes, 12 pruned nodes, max_depth=12
# [172]#011train-auc:0.903632#011validation-auc:0.723314
# [18:39:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 308 extra nodes, 34 pruned nodes, max_depth=12
# [173]#011train-auc:0.903996#011validation-auc:0.723377
# [18:39:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 352 extra nodes, 22 pruned nodes, max_depth=12
# [174]#011train-auc:0.90451#011validation-auc:0.723462
# [18:39:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 578 extra nodes, 50 pruned nodes, max_depth=12
# [175]#011train-auc:0.90547#011validation-auc:0.723603
# [18:39:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 544 extra nodes, 36 pruned nodes, max_depth=12
# [176]#011train-auc:0.906371#011validation-auc:0.723772
# [18:39:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 850 extra nodes, 42 pruned nodes, max_depth=12
# [177]#011train-auc:0.907707#011validation-auc:0.723962
# [18:39:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 360 extra nodes, 26 pruned nodes, max_depth=12
# [178]#011train-auc:0.908188#011validation-auc:0.724006
# [18:39:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 444 extra nodes, 28 pruned nodes, max_depth=12
# [179]#011train-auc:0.908853#011validation-auc:0.724198
# [18:39:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 318 extra nodes, 28 pruned nodes, max_depth=12
# [180]#011train-auc:0.90927#011validation-auc:0.724166
# [18:39:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 138 extra nodes, 4 pruned nodes, max_depth=12
# [181]#011train-auc:0.909447#011validation-auc:0.724188
# [18:39:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 254 extra nodes, 22 pruned nodes, max_depth=12
# [182]#011train-auc:0.90972#011validation-auc:0.724174
# [18:39:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 170 extra nodes, 18 pruned nodes, max_depth=12
# [183]#011train-auc:0.90989#011validation-auc:0.724182
# [18:39:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 350 extra nodes, 16 pruned nodes, max_depth=12
# [184]#011train-auc:0.910403#011validation-auc:0.724285
# [18:39:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 546 extra nodes, 24 pruned nodes, max_depth=12
# [185]#011train-auc:0.911198#011validation-auc:0.724355
# [18:39:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 282 extra nodes, 18 pruned nodes, max_depth=12
# [186]#011train-auc:0.911529#011validation-auc:0.724438
# [18:39:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 254 extra nodes, 32 pruned nodes, max_depth=12
# [187]#011train-auc:0.91176#011validation-auc:0.724431
# [18:39:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 318 extra nodes, 14 pruned nodes, max_depth=12
# [188]#011train-auc:0.912127#011validation-auc:0.724362
# [18:39:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 458 extra nodes, 38 pruned nodes, max_depth=12
# [189]#011train-auc:0.912815#011validation-auc:0.724486
# [18:39:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 258 extra nodes, 10 pruned nodes, max_depth=12
# [190]#011train-auc:0.913009#011validation-auc:0.724506
# [18:39:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 228 extra nodes, 10 pruned nodes, max_depth=12
# [191]#011train-auc:0.913184#011validation-auc:0.724527
# [18:39:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 482 extra nodes, 34 pruned nodes, max_depth=12
# [192]#011train-auc:0.913758#011validation-auc:0.724678
# [18:39:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 438 extra nodes, 50 pruned nodes, max_depth=12
# [193]#011train-auc:0.914398#011validation-auc:0.724847
# [18:39:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 458 extra nodes, 32 pruned nodes, max_depth=12
# [194]#011train-auc:0.915028#011validation-auc:0.724996
# [18:39:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 390 extra nodes, 18 pruned nodes, max_depth=12
# [195]#011train-auc:0.915604#011validation-auc:0.725011
# [18:39:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 346 extra nodes, 24 pruned nodes, max_depth=12
# [196]#011train-auc:0.915954#011validation-auc:0.725034
# [18:39:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 500 extra nodes, 28 pruned nodes, max_depth=12
# [197]#011train-auc:0.916591#011validation-auc:0.725079
# [18:39:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 140 extra nodes, 6 pruned nodes, max_depth=12
# [198]#011train-auc:0.916727#011validation-auc:0.725108
# [18:39:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 296 extra nodes, 28 pruned nodes, max_depth=12
# [199]#011train-auc:0.916999#011validation-auc:0.725184
# [18:39:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 436 extra nodes, 32 pruned nodes, max_depth=12
# [200]#011train-auc:0.917626#011validation-auc:0.725365
# [18:39:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 380 extra nodes, 34 pruned nodes, max_depth=12
# [201]#011train-auc:0.918135#011validation-auc:0.725442
# [18:39:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 216 extra nodes, 22 pruned nodes, max_depth=12
# [202]#011train-auc:0.918338#011validation-auc:0.725462
# [18:39:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 360 extra nodes, 8 pruned nodes, max_depth=12
# [203]#011train-auc:0.918764#011validation-auc:0.725521
# [18:39:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 358 extra nodes, 24 pruned nodes, max_depth=12
# [204]#011train-auc:0.91921#011validation-auc:0.725553
# [18:39:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 380 extra nodes, 18 pruned nodes, max_depth=12
# [205]#011train-auc:0.91962#011validation-auc:0.725646
# [18:39:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 372 extra nodes, 22 pruned nodes, max_depth=12
# [206]#011train-auc:0.920041#011validation-auc:0.7257
# [18:39:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 206 extra nodes, 10 pruned nodes, max_depth=12
# [207]#011train-auc:0.920184#011validation-auc:0.725662
# [18:39:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 528 extra nodes, 26 pruned nodes, max_depth=12
# [208]#011train-auc:0.920915#011validation-auc:0.725812
# [18:39:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 90 extra nodes, 6 pruned nodes, max_depth=12
# [209]#011train-auc:0.920939#011validation-auc:0.725842
# [18:39:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 348 extra nodes, 28 pruned nodes, max_depth=12
# [210]#011train-auc:0.921236#011validation-auc:0.725904
# [18:39:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 526 extra nodes, 26 pruned nodes, max_depth=12
# [211]#011train-auc:0.921904#011validation-auc:0.725955
# [18:39:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 534 extra nodes, 38 pruned nodes, max_depth=12
# [212]#011train-auc:0.922592#011validation-auc:0.726048
# [18:39:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 288 extra nodes, 16 pruned nodes, max_depth=12
# [213]#011train-auc:0.92291#011validation-auc:0.726123
# [18:39:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 426 extra nodes, 32 pruned nodes, max_depth=12
# [214]#011train-auc:0.923358#011validation-auc:0.726176
# [18:39:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 298 extra nodes, 20 pruned nodes, max_depth=12
# [215]#011train-auc:0.923628#011validation-auc:0.726282
# [18:39:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 646 extra nodes, 50 pruned nodes, max_depth=12
# [216]#011train-auc:0.924548#011validation-auc:0.726422
# [18:39:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 178 extra nodes, 14 pruned nodes, max_depth=12
# [217]#011train-auc:0.924691#011validation-auc:0.726452
# [18:39:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 376 extra nodes, 30 pruned nodes, max_depth=12
# [218]#011train-auc:0.925116#011validation-auc:0.726494
# [18:39:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 482 extra nodes, 28 pruned nodes, max_depth=12
# [219]#011train-auc:0.925584#011validation-auc:0.726565
# [18:39:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 366 extra nodes, 26 pruned nodes, max_depth=12
# [220]#011train-auc:0.925959#011validation-auc:0.726588
# [18:39:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 322 extra nodes, 34 pruned nodes, max_depth=12
# [221]#011train-auc:0.926289#011validation-auc:0.726654
# [18:39:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 248 extra nodes, 18 pruned nodes, max_depth=12
# [222]#011train-auc:0.92655#011validation-auc:0.726669
# [18:39:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 212 extra nodes, 10 pruned nodes, max_depth=12
# [223]#011train-auc:0.926705#011validation-auc:0.726691
# [18:39:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 302 extra nodes, 32 pruned nodes, max_depth=12
# [224]#011train-auc:0.926993#011validation-auc:0.726805
# [18:39:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 254 extra nodes, 16 pruned nodes, max_depth=12
# [225]#011train-auc:0.927159#011validation-auc:0.726788
# [18:39:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 298 extra nodes, 24 pruned nodes, max_depth=12
# [226]#011train-auc:0.927435#011validation-auc:0.726892
# [18:39:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 230 extra nodes, 12 pruned nodes, max_depth=12
# [227]#011train-auc:0.927641#011validation-auc:0.72695
# [18:39:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 474 extra nodes, 18 pruned nodes, max_depth=12
# [228]#011train-auc:0.928201#011validation-auc:0.727084
# [18:39:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 138 extra nodes, 12 pruned nodes, max_depth=12
# [229]#011train-auc:0.928314#011validation-auc:0.72708
# [18:39:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 176 extra nodes, 14 pruned nodes, max_depth=12
# [230]#011train-auc:0.928442#011validation-auc:0.727112
# [18:39:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 452 extra nodes, 40 pruned nodes, max_depth=12
# [231]#011train-auc:0.928888#011validation-auc:0.727142
# [18:39:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 166 extra nodes, 10 pruned nodes, max_depth=12
# [232]#011train-auc:0.929036#011validation-auc:0.727202
# [18:39:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 474 extra nodes, 50 pruned nodes, max_depth=12
# [233]#011train-auc:0.929615#011validation-auc:0.727219
# [18:39:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 248 extra nodes, 42 pruned nodes, max_depth=12
# [234]#011train-auc:0.929765#011validation-auc:0.727228
# [18:39:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 438 extra nodes, 22 pruned nodes, max_depth=12
# [235]#011train-auc:0.930204#011validation-auc:0.727344
# [18:39:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 454 extra nodes, 32 pruned nodes, max_depth=12
# [236]#011train-auc:0.930775#011validation-auc:0.727452
# [18:39:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 228 extra nodes, 12 pruned nodes, max_depth=12
# [237]#011train-auc:0.93102#011validation-auc:0.727538
# [18:39:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 422 extra nodes, 28 pruned nodes, max_depth=12
# [238]#011train-auc:0.931379#011validation-auc:0.727652
# [18:39:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 426 extra nodes, 36 pruned nodes, max_depth=12
# [239]#011train-auc:0.931849#011validation-auc:0.727691
# [18:39:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 108 extra nodes, 8 pruned nodes, max_depth=12
# [240]#011train-auc:0.931874#011validation-auc:0.727692
# [18:39:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 654 extra nodes, 60 pruned nodes, max_depth=12
# [241]#011train-auc:0.932606#011validation-auc:0.727636
# [18:39:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 310 extra nodes, 36 pruned nodes, max_depth=12
# [242]#011train-auc:0.932892#011validation-auc:0.727694
# [18:39:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 320 extra nodes, 22 pruned nodes, max_depth=12
# [243]#011train-auc:0.933147#011validation-auc:0.727731
# [18:39:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 390 extra nodes, 16 pruned nodes, max_depth=12
# [244]#011train-auc:0.933649#011validation-auc:0.727722
# [18:39:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 392 extra nodes, 26 pruned nodes, max_depth=12
# [245]#011train-auc:0.934078#011validation-auc:0.72785
# [18:39:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 450 extra nodes, 32 pruned nodes, max_depth=12
# [246]#011train-auc:0.934537#011validation-auc:0.727825
# [18:39:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 326 extra nodes, 28 pruned nodes, max_depth=12
# [247]#011train-auc:0.934873#011validation-auc:0.727971
# [18:39:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 300 extra nodes, 28 pruned nodes, max_depth=12
# [248]#011train-auc:0.935097#011validation-auc:0.727997
# [18:39:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 462 extra nodes, 28 pruned nodes, max_depth=12
# [249]#011train-auc:0.935587#011validation-auc:0.728059
# [18:39:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 276 extra nodes, 14 pruned nodes, max_depth=12
# [250]#011train-auc:0.935767#011validation-auc:0.728108
# [18:39:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 302 extra nodes, 34 pruned nodes, max_depth=12
# [251]#011train-auc:0.936028#011validation-auc:0.728122
# [18:39:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 482 extra nodes, 46 pruned nodes, max_depth=12
# [252]#011train-auc:0.936539#011validation-auc:0.728139
# [18:39:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 432 extra nodes, 32 pruned nodes, max_depth=12
# [253]#011train-auc:0.936969#011validation-auc:0.728182
# [18:39:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 300 extra nodes, 16 pruned nodes, max_depth=12
# [254]#011train-auc:0.937272#011validation-auc:0.728151
# [18:39:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 546 extra nodes, 36 pruned nodes, max_depth=12
# [255]#011train-auc:0.937876#011validation-auc:0.728275
# [18:39:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 298 extra nodes, 40 pruned nodes, max_depth=12
# [256]#011train-auc:0.93809#011validation-auc:0.72829
# [18:39:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 362 extra nodes, 14 pruned nodes, max_depth=12
# [257]#011train-auc:0.938466#011validation-auc:0.728273
# [18:39:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 480 extra nodes, 46 pruned nodes, max_depth=12
# [258]#011train-auc:0.938906#011validation-auc:0.728363
# [18:39:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 388 extra nodes, 26 pruned nodes, max_depth=12
# [259]#011train-auc:0.939265#011validation-auc:0.728478
# [18:39:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 540 extra nodes, 26 pruned nodes, max_depth=12
# [260]#011train-auc:0.93973#011validation-auc:0.728543
# [18:39:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 214 extra nodes, 10 pruned nodes, max_depth=12
# [261]#011train-auc:0.93985#011validation-auc:0.728539
# [18:39:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 284 extra nodes, 22 pruned nodes, max_depth=12
# [262]#011train-auc:0.940096#011validation-auc:0.728559
# [18:39:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 514 extra nodes, 36 pruned nodes, max_depth=12
# [263]#011train-auc:0.940596#011validation-auc:0.728677
# [18:39:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 464 extra nodes, 26 pruned nodes, max_depth=12
# [264]#011train-auc:0.941023#011validation-auc:0.728766
# [18:39:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 538 extra nodes, 50 pruned nodes, max_depth=12
# [265]#011train-auc:0.941526#011validation-auc:0.728806
# [18:39:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 506 extra nodes, 34 pruned nodes, max_depth=12
# [266]#011train-auc:0.941968#011validation-auc:0.728809
# [18:39:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 276 extra nodes, 18 pruned nodes, max_depth=12
# [267]#011train-auc:0.942161#011validation-auc:0.728881
# [18:39:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 432 extra nodes, 30 pruned nodes, max_depth=12
# [268]#011train-auc:0.942515#011validation-auc:0.728984
# [18:39:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 306 extra nodes, 26 pruned nodes, max_depth=12
# [269]#011train-auc:0.942803#011validation-auc:0.72909
# [18:39:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 378 extra nodes, 36 pruned nodes, max_depth=12
# [270]#011train-auc:0.943147#011validation-auc:0.72921
# [18:39:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 294 extra nodes, 20 pruned nodes, max_depth=12
# [271]#011train-auc:0.943395#011validation-auc:0.729304
# [18:39:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 178 extra nodes, 18 pruned nodes, max_depth=12
# [272]#011train-auc:0.943472#011validation-auc:0.729356
# [18:39:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 400 extra nodes, 46 pruned nodes, max_depth=12
# [273]#011train-auc:0.943863#011validation-auc:0.729363
# [18:39:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 392 extra nodes, 36 pruned nodes, max_depth=12
# [274]#011train-auc:0.944207#011validation-auc:0.729373
# ...
# [427]#011train-auc:0.974012#011validation-auc:0.735485
# [18:39:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 418 extra nodes, 40 pruned nodes, max_depth=12
# [428]#011train-auc:0.974179#011validation-auc:0.735525
# [18:39:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 422 extra nodes, 36 pruned nodes, max_depth=12
# [429]#011train-auc:0.97433#011validation-auc:0.735597
# [18:39:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 384 extra nodes, 34 pruned nodes, max_depth=12
# [430]#011train-auc:0.974453#011validation-auc:0.735582
# [18:39:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 312 extra nodes, 30 pruned nodes, max_depth=12
# [431]#011train-auc:0.974564#011validation-auc:0.735563
# [18:39:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 332 extra nodes, 32 pruned nodes, max_depth=12
# [432]#011train-auc:0.974689#011validation-auc:0.735557
# [18:39:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 342 extra nodes, 36 pruned nodes, max_depth=12
# [433]#011train-auc:0.974795#011validation-auc:0.735558
# [18:39:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 284 extra nodes, 62 pruned nodes, max_depth=12
# [434]#011train-auc:0.974882#011validation-auc:0.7356
# [18:39:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 492 extra nodes, 42 pruned nodes, max_depth=12
# [435]#011train-auc:0.975122#011validation-auc:0.73573
# [18:39:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 286 extra nodes, 46 pruned nodes, max_depth=12
# [436]#011train-auc:0.975222#011validation-auc:0.735737
# [18:39:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 390 extra nodes, 60 pruned nodes, max_depth=12
# [437]#011train-auc:0.975366#011validation-auc:0.73576
# [18:40:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 358 extra nodes, 30 pruned nodes, max_depth=12
# [438]#011train-auc:0.975491#011validation-auc:0.735799
# [18:40:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 580 extra nodes, 72 pruned nodes, max_depth=12
# [439]#011train-auc:0.975719#011validation-auc:0.735861
# [18:40:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 488 extra nodes, 46 pruned nodes, max_depth=12
# [440]#011train-auc:0.975895#011validation-auc:0.735833
# [18:40:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 318 extra nodes, 30 pruned nodes, max_depth=12
# [441]#011train-auc:0.975991#011validation-auc:0.735814
# [18:40:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 414 extra nodes, 26 pruned nodes, max_depth=12
# [442]#011train-auc:0.976109#011validation-auc:0.735806
# [18:40:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 226 extra nodes, 34 pruned nodes, max_depth=12
# [443]#011train-auc:0.976163#011validation-auc:0.735878
# [18:40:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 554 extra nodes, 58 pruned nodes, max_depth=12
# [444]#011train-auc:0.976396#011validation-auc:0.73596
# [18:40:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 360 extra nodes, 44 pruned nodes, max_depth=12
# [445]#011train-auc:0.976501#011validation-auc:0.735992
# [18:40:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 232 extra nodes, 12 pruned nodes, max_depth=12
# [446]#011train-auc:0.976551#011validation-auc:0.736008
# [18:40:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 374 extra nodes, 24 pruned nodes, max_depth=12
# [447]#011train-auc:0.976714#011validation-auc:0.736016
# [18:40:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 200 extra nodes, 28 pruned nodes, max_depth=12
# [448]#011train-auc:0.976771#011validation-auc:0.736027
# [18:40:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 274 extra nodes, 36 pruned nodes, max_depth=12
# [449]#011train-auc:0.97687#011validation-auc:0.73603
# [18:40:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 280 extra nodes, 18 pruned nodes, max_depth=12
# [450]#011train-auc:0.976931#011validation-auc:0.736059
# [18:40:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 214 extra nodes, 36 pruned nodes, max_depth=12
# [451]#011train-auc:0.976986#011validation-auc:0.736083
# [18:40:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 294 extra nodes, 44 pruned nodes, max_depth=12
# [452]#011train-auc:0.977071#011validation-auc:0.736108
# [18:40:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 440 extra nodes, 56 pruned nodes, max_depth=12
# [453]#011train-auc:0.977258#011validation-auc:0.736213
# [18:40:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 424 extra nodes, 46 pruned nodes, max_depth=12
# [454]#011train-auc:0.977441#011validation-auc:0.736319
# [18:40:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 440 extra nodes, 50 pruned nodes, max_depth=12
# [455]#011train-auc:0.977591#011validation-auc:0.736398
# [18:40:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 486 extra nodes, 68 pruned nodes, max_depth=12
# [456]#011train-auc:0.977777#011validation-auc:0.736343
# [18:40:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 338 extra nodes, 38 pruned nodes, max_depth=12
# [457]#011train-auc:0.977866#011validation-auc:0.73637
# [18:40:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 424 extra nodes, 58 pruned nodes, max_depth=12
# [458]#011train-auc:0.978013#011validation-auc:0.73644
# [18:40:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 628 extra nodes, 68 pruned nodes, max_depth=12
# [459]#011train-auc:0.978263#011validation-auc:0.736492
# [18:40:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 428 extra nodes, 64 pruned nodes, max_depth=12
# [460]#011train-auc:0.978414#011validation-auc:0.736547
# [18:40:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 234 extra nodes, 32 pruned nodes, max_depth=12
# [461]#011train-auc:0.978454#011validation-auc:0.73652
# [18:40:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 490 extra nodes, 52 pruned nodes, max_depth=12
# [462]#011train-auc:0.978623#011validation-auc:0.736532
# [18:40:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 428 extra nodes, 48 pruned nodes, max_depth=12
# [463]#011train-auc:0.978753#011validation-auc:0.736543
# [18:40:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 312 extra nodes, 40 pruned nodes, max_depth=12
# [464]#011train-auc:0.9788#011validation-auc:0.736454
# [18:40:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 332 extra nodes, 40 pruned nodes, max_depth=12
# [465]#011train-auc:0.97888#011validation-auc:0.73646
# [18:40:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 482 extra nodes, 50 pruned nodes, max_depth=12
# [466]#011train-auc:0.979044#011validation-auc:0.7365
# [18:40:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 540 extra nodes, 62 pruned nodes, max_depth=12
# [467]#011train-auc:0.979239#011validation-auc:0.736592
# [18:40:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 404 extra nodes, 40 pruned nodes, max_depth=12
# [468]#011train-auc:0.979361#011validation-auc:0.736638
# [18:40:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 188 extra nodes, 18 pruned nodes, max_depth=12
# [469]#011train-auc:0.979422#011validation-auc:0.736686
# [18:40:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 414 extra nodes, 74 pruned nodes, max_depth=12
# [470]#011train-auc:0.979538#011validation-auc:0.736701
# [18:40:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 392 extra nodes, 44 pruned nodes, max_depth=12
# [471]#011train-auc:0.979661#011validation-auc:0.736757
# [18:40:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 362 extra nodes, 42 pruned nodes, max_depth=12
# [472]#011train-auc:0.979759#011validation-auc:0.736786
# [18:40:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 304 extra nodes, 34 pruned nodes, max_depth=12
# [473]#011train-auc:0.97982#011validation-auc:0.736791
# [18:40:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 344 extra nodes, 36 pruned nodes, max_depth=12
# [474]#011train-auc:0.979923#011validation-auc:0.736849
# [18:40:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 336 extra nodes, 58 pruned nodes, max_depth=12
# [475]#011train-auc:0.979997#011validation-auc:0.736823
# [18:40:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 346 extra nodes, 28 pruned nodes, max_depth=12
# [476]#011train-auc:0.980096#011validation-auc:0.736799
# [18:40:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 320 extra nodes, 42 pruned nodes, max_depth=12
# [477]#011train-auc:0.980179#011validation-auc:0.7368
# [18:40:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 254 extra nodes, 34 pruned nodes, max_depth=12
# [478]#011train-auc:0.980275#011validation-auc:0.736874
# [18:40:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 388 extra nodes, 56 pruned nodes, max_depth=12
# [479]#011train-auc:0.9804#011validation-auc:0.736857
# [18:40:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 376 extra nodes, 50 pruned nodes, max_depth=12
# [480]#011train-auc:0.98049#011validation-auc:0.73697
# [18:40:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 300 extra nodes, 22 pruned nodes, max_depth=12
# [481]#011train-auc:0.980544#011validation-auc:0.736982
# [18:40:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 424 extra nodes, 46 pruned nodes, max_depth=12
# [482]#011train-auc:0.980697#011validation-auc:0.737102
# [18:40:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 360 extra nodes, 40 pruned nodes, max_depth=12
# [483]#011train-auc:0.980799#011validation-auc:0.737143
# [18:40:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 146 extra nodes, 18 pruned nodes, max_depth=12
# [484]#011train-auc:0.980799#011validation-auc:0.737162
# [18:40:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 262 extra nodes, 32 pruned nodes, max_depth=12
# [485]#011train-auc:0.98086#011validation-auc:0.737184
# [18:40:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 336 extra nodes, 36 pruned nodes, max_depth=12
# [486]#011train-auc:0.980949#011validation-auc:0.737148
# [18:40:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 262 extra nodes, 36 pruned nodes, max_depth=12
# [487]#011train-auc:0.981024#011validation-auc:0.737203
# [18:40:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 456 extra nodes, 64 pruned nodes, max_depth=12
# [488]#011train-auc:0.981142#011validation-auc:0.737252
# [18:40:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 354 extra nodes, 52 pruned nodes, max_depth=12
# [489]#011train-auc:0.981227#011validation-auc:0.737206
# [18:40:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 508 extra nodes, 64 pruned nodes, max_depth=12
# [490]#011train-auc:0.981403#011validation-auc:0.73722
# [18:40:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 334 extra nodes, 40 pruned nodes, max_depth=12
# [491]#011train-auc:0.981481#011validation-auc:0.737198
# [18:40:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 152 extra nodes, 16 pruned nodes, max_depth=12
# [492]#011train-auc:0.981499#011validation-auc:0.737188
# [18:40:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 294 extra nodes, 38 pruned nodes, max_depth=12
# [493]#011train-auc:0.981582#011validation-auc:0.737229
# [18:40:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 576 extra nodes, 60 pruned nodes, max_depth=12
# [494]#011train-auc:0.981771#011validation-auc:0.737294
# [18:40:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 278 extra nodes, 60 pruned nodes, max_depth=12
# [495]#011train-auc:0.981847#011validation-auc:0.737294
# [18:40:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 348 extra nodes, 20 pruned nodes, max_depth=12
# [496]#011train-auc:0.981945#011validation-auc:0.737372
# [18:40:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 344 extra nodes, 52 pruned nodes, max_depth=12
# [497]#011train-auc:0.982016#011validation-auc:0.737463
# [18:40:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 348 extra nodes, 30 pruned nodes, max_depth=12
# [498]#011train-auc:0.982107#011validation-auc:0.73753
# [18:40:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 358 extra nodes, 42 pruned nodes, max_depth=12
# [499]#011train-auc:0.982206#011validation-auc:0.737531
# Parameter image will be renamed to image_uri in SageMaker Python SDK v2.
# Training seconds: 168
# Billable seconds: 168
# ..................................Arguments: serve
# [2022-01-04 18:50:19 +0000] [1] [INFO] Starting gunicorn 19.9.0
# [2022-01-04 18:50:19 +0000] [1] [INFO] Listening at: http://0.0.0.0:8080 (1)
# [2022-01-04 18:50:19 +0000] [1] [INFO] Using worker: gevent
# [2022-01-04 18:50:19 +0000] [21] [INFO] Booting worker with pid: 21
# [2022-01-04 18:50:19 +0000] [22] [INFO] Booting worker with pid: 22
# /opt/amazon/lib/python3.7/site-packages/gunicorn/workers/ggevent.py:65: MonkeyPatchWarning: Monkey-patching ssl after ssl has already been imported may lead to errors, including RecursionError on Python 3.6. It may also silently lead to incorrect behaviour on Python 3.7. Please monkey-patch earlier. See https://github.com/gevent/gevent/issues/1016. Modules that had direct imports (NOT patched): ['urllib3.util.ssl_ (/opt/amazon/lib/python3.7/site-packages/urllib3/util/ssl_.py)', 'urllib3.util (/opt/amazon/lib/python3.7/site-packages/urllib3/util/__init__.py)'].
#   monkey.patch_all(subprocess=True)
# [2022-01-04:18:50:19:INFO] Model loaded successfully for worker : 21
# /opt/amazon/lib/python3.7/site-packages/gunicorn/workers/ggevent.py:65: MonkeyPatchWarning: Monkey-patching ssl after ssl has already been imported may lead to errors, including RecursionError on Python 3.6. It may also silently lead to incorrect behaviour on Python 3.7. Please monkey-patch earlier. See https://github.com/gevent/gevent/issues/1016. Modules that had direct imports (NOT patched): ['urllib3.util.ssl_ (/opt/amazon/lib/python3.7/site-packages/urllib3/util/ssl_.py)', 'urllib3.util (/opt/amazon/lib/python3.7/site-packages/urllib3/util/__init__.py)'].
#   monkey.patch_all(subprocess=True)
# [2022-01-04 18:50:19 +0000] [23] [INFO] Booting worker with pid: 23
# [2022-01-04:18:50:19:INFO] Model loaded successfully for worker : 22
# [2022-01-04 18:50:19 +0000] [24] [INFO] Booting worker with pid: 24
# /opt/amazon/lib/python3.7/site-packages/gunicorn/workers/ggevent.py:65: MonkeyPatchWarning: Monkey-patching ssl after ssl has already been imported may lead to errors, including RecursionError on Python 3.6. It may also silently lead to incorrect behaviour on Python 3.7. Please monkey-patch earlier. See https://github.com/gevent/gevent/issues/1016. Modules that had direct imports (NOT patched): ['urllib3.util.ssl_ (/opt/amazon/lib/python3.7/site-packages/urllib3/util/ssl_.py)', 'urllib3.util (/opt/amazon/lib/python3.7/site-packages/urllib3/util/__init__.py)'].
#   monkey.patch_all(subprocess=True)
# /opt/amazon/lib/python3.7/site-packages/gunicorn/workers/ggevent.py:65: MonkeyPatchWarning: Monkey-patching ssl after ssl has already been imported may lead to errors, including RecursionError on Python 3.6. It may also silently lead to incorrect behaviour on Python 3.7. Please monkey-patch earlier. See https://github.com/gevent/gevent/issues/1016. Modules that had direct imports (NOT patched): ['urllib3.util.ssl_ (/opt/amazon/lib/python3.7/site-packages/urllib3/util/ssl_.py)', 'urllib3.util (/opt/amazon/lib/python3.7/site-packages/urllib3/util/__init__.py)'].
#   monkey.patch_all(subprocess=True)
# [2022-01-04:18:50:19:INFO] Model loaded successfully for worker : 23
# [2022-01-04:18:50:19:INFO] Model loaded successfully for worker : 24
# [2022-01-04:18:50:23:INFO] Sniff delimiter as ','
# [2022-01-04:18:50:23:INFO] Determined delimiter of CSV input is ','
# [2022-01-04:18:50:23:INFO] Sniff delimiter as ','
# [2022-01-04:18:50:23:INFO] Determined delimiter of CSV input is ','
# 2022-01-04T18:50:22.981:[sagemaker logs]: MaxConcurrentTransforms=4, MaxPayloadInMB=6, BatchStrategy=MULTI_RECORD

# %%
## Download tranform output from s3 location ##
# !aws s3 cp --recursive $xgb_transformer.output_path $data_dir/xgb_results
# Out:
# download: s3://sagemaker-us-east-1-345989147144/xgboost-220104-1801-020-557217e0-2022-01-04-18-44-47-135/test.csv.out to data/xgb_results/test.csv.out

# %%
## Calculate test accuracy and auc performance ##
output = pd.read_csv(os.path.join(data_dir, 'xgb_results/test.csv.out'), header=None)
predictions = [round(num) for num in output.squeeze().values]
probs = [p for p in output.squeeze().values]

from sklearn.metrics import accuracy_score, roc_auc_score
print ('XBG test accuracy: {}'.format(accuracy_score(y_test, predictions)))
print ('XBG test auc: {}'.format(roc_auc_score(y_test, probs)))
# Out:
# XBG test accuracy: 0.6730962167060422
# XBG test auc: 0.734728073721581
