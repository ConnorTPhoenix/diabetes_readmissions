# %%
# !pip install sagemaker==1.72.0

# %%
## Import relevant libraries
import os
import boto3
import re
import sagemaker
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import io
import time
import json
import sagemaker.amazon.common as smac
import scipy
from sklearn.model_selection import train_test_split
from sagemaker.amazon.amazon_estimator import get_image_uri

## Defin role, region, session, and default s3 bucket ##
role = sagemaker.get_execution_role()
region = boto3.Session().region_name
session = sagemaker.Session()
bucket = session.default_bucket()

# %%
## Read in processed datasets ##
X_sparse = scipy.sparse.load_npz('./readmissions_X.npz')
y_sparse = scipy.sparse.load_npz('./readmissions_y.npz')
X = pd.DataFrame(np.array(X_sparse.todense()))
y = pd.DataFrame(np.array(y_sparse.todense()).reshape(-1,1))

# %%
## Create train/test/validation sets ##
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.33)

# %%
X_test.shape
# Out:
# (30899, 105)

# %%
y_test.shape
# Out:
# (30899, 1)

# %% [markdown]
# #### Build XGboost Classifier

# %%
prefix = 'readmission-xgboost'
data_dir = './data/xgb/'
if not os.path.exists(data_dir):
    os.makedirs(data_dir)

## Save train/test/validation sets to local data directory ##
pd.DataFrame(X_test).to_csv(os.path.join(data_dir, 'X_test.csv'), header=False, index=False)
pd.DataFrame(y_test).to_csv(os.path.join(data_dir, 'y_test.csv'), header=False, index=False)
pd.concat([y_val, X_val], axis=1).to_csv(os.path.join(data_dir, 'validation.csv'), header=False, index=False)
pd.concat([y_train, X_train], axis=1).to_csv(os.path.join(data_dir, 'train.csv'), header=False, index=False)

## Upload train/test/validation sets from local directory to s3 bucket ##
test_location = session.upload_data(os.path.join(data_dir, 'X_test.csv'), key_prefix=prefix)
val_location = session.upload_data(os.path.join(data_dir, 'validation.csv'), key_prefix=prefix)
train_location = session.upload_data(os.path.join(data_dir, 'train.csv'), key_prefix=prefix)

# %%
## Define estimator object
from sagemaker.tuner import IntegerParameter, ContinuousParameter, HyperparameterTuner
container = get_image_uri(session.boto_region_name, 'xgboost')
xgb = sagemaker.estimator.Estimator(container, 
                                    role,                                   
                                    train_instance_count=1,                 
                                    train_instance_type='ml.m4.xlarge',    
                                    output_path='s3://{}/{}/output'.format(bucket, prefix),
                                    sagemaker_session=session)
# Out:
# 'get_image_uri' method will be deprecated in favor of 'ImageURIProvider' class in SageMaker Python SDK v2.
# There is a more up to date SageMaker XGBoost image. To use the newer image, please set 'repo_version'='1.0-1'. For example:
# 	get_image_uri(region, 'xgboost', '1.0-1').
# Parameter image_name will be renamed to image_uri in SageMaker Python SDK v2.

# %%
## Define default and tunable hyperparameters ## 
xgb.set_hyperparameters(silent=0,
                        objective='binary:logistic',
                        early_stopping_rounds=10,
                        num_round=500)

xgb_hyperparameter_tuner = HyperparameterTuner(estimator = xgb, 
                                               objective_metric_name = 'validation:auc', 
                                               objective_type = 'Maximize',
                                               max_jobs = 20,
                                               max_parallel_jobs = 3,
                                               hyperparameter_ranges = {
                                                    'max_depth': IntegerParameter(3, 12),
                                                    'eta'      : ContinuousParameter(0.05, 0.5),
                                                    'min_child_weight': IntegerParameter(2, 8),
                                                    'subsample': ContinuousParameter(0.5, 0.9),
                                                    'gamma': ContinuousParameter(0, 10)})

# %%
## Point hyperparameter tuner object to training/validation data in s3 ##
s3_input_train = sagemaker.s3_input(s3_data=train_location, content_type='csv')
s3_input_validation = sagemaker.s3_input(s3_data=val_location, content_type='csv')
# Out:
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.

# %%
## Fit hyperparameter tuner object ##
xgb_hyperparameter_tuner.fit({'train': s3_input_train, 'validation': s3_input_validation})
xgb_hyperparameter_tuner.wait()
# Out:
# ..........................................................................................................................................................................................................................................................................................................................................................................................................................!

# %%
## View Hyperparameters and performance for best job ##
analytics = xgb_hyperparameter_tuner.analytics()
analytics_df = analytics.dataframe()

best_job = xgb_hyperparameter_tuner.best_training_job()
analytics_df[analytics_df['TrainingJobName'] == best_job]
# Out:
#         eta     gamma  max_depth  min_child_weight  subsample  \
# 1  0.154636  0.757286       12.0               2.0   0.888536
#
#                     TrainingJobName TrainingJobStatus  FinalObjectiveValue  \
# 1  xgboost-220107-1704-019-09793d10         Completed             0.735732
#
#           TrainingStartTime           TrainingEndTime  \
# 1 2022-01-07 17:36:26+00:00 2022-01-07 17:38:35+00:00
#
#    TrainingElapsedTimeSeconds
# 1                       129.0

# %%
## Create a new estimator object using the "best training job" ##
xgb_best = sagemaker.estimator.Estimator.attach(xgb_hyperparameter_tuner.best_training_job())

## Create a batch transform job and point to s3 training data location ##
xgb_transformer = xgb_best.transformer(instance_count = 1, instance_type = 'ml.m4.xlarge')
xgb_transformer.transform(test_location, content_type='text/csv', split_type='Line')
xgb_transformer.wait()
# Out:
# Parameter image_name will be renamed to image_uri in SageMaker Python SDK v2.
# 2022-01-07 17:38:35 Starting - Preparing the instances for training
# 2022-01-07 17:38:35 Downloading - Downloading input data
# 2022-01-07 17:38:35 Training - Training image download completed. Training in progress.
# 2022-01-07 17:38:35 Uploading - Uploading generated training model
# 2022-01-07 17:38:35 Completed - Training job completedArguments: train
# [2022-01-07:17:37:26:INFO] Running standalone xgboost training.
# [2022-01-07:17:37:26:INFO] Setting up HPO optimized metric to be : auc
# [2022-01-07:17:37:26:INFO] File size need to be processed in the node: 12.79mb. Available memory size in the node: 8381.38mb
# [2022-01-07:17:37:26:INFO] Determined delimiter of CSV input is ','
# [17:37:26] S3DistributionType set as FullyReplicated
# [17:37:26] 42031x105 matrix with 4413255 entries loaded from /opt/ml/input/data/train?format=csv&label_column=0&delimiter=,
# [2022-01-07:17:37:26:INFO] Determined delimiter of CSV input is ','
# [17:37:26] S3DistributionType set as FullyReplicated
# [17:37:27] 20702x105 matrix with 2173710 entries loaded from /opt/ml/input/data/validation?format=csv&label_column=0&delimiter=,
# [17:37:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1142 extra nodes, 60 pruned nodes, max_depth=12
# [0]#011train-auc:0.722567#011validation-auc:0.652248
# Multiple eval metrics have been passed: 'validation-auc' will be used for early stopping.
# Will train until validation-auc hasn't improved in 10 rounds.
# [17:37:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1080 extra nodes, 78 pruned nodes, max_depth=12
# [1]#011train-auc:0.744542#011validation-auc:0.667551
# [17:37:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1136 extra nodes, 76 pruned nodes, max_depth=12
# [2]#011train-auc:0.759951#011validation-auc:0.67593
# [17:37:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 896 extra nodes, 74 pruned nodes, max_depth=12
# [3]#011train-auc:0.766203#011validation-auc:0.680274
# [17:37:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1200 extra nodes, 74 pruned nodes, max_depth=12
# [4]#011train-auc:0.77757#011validation-auc:0.682356
# [17:37:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1032 extra nodes, 124 pruned nodes, max_depth=12
# [5]#011train-auc:0.784721#011validation-auc:0.684852
# [17:37:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 894 extra nodes, 98 pruned nodes, max_depth=12
# [6]#011train-auc:0.790409#011validation-auc:0.686667
# [17:37:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 932 extra nodes, 86 pruned nodes, max_depth=12
# [7]#011train-auc:0.796088#011validation-auc:0.688255
# [17:37:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 772 extra nodes, 72 pruned nodes, max_depth=12
# [8]#011train-auc:0.799226#011validation-auc:0.689755
# [17:37:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 832 extra nodes, 68 pruned nodes, max_depth=12
# [9]#011train-auc:0.803281#011validation-auc:0.689854
# [17:37:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 580 extra nodes, 58 pruned nodes, max_depth=12
# [10]#011train-auc:0.805319#011validation-auc:0.691372
# [17:37:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 856 extra nodes, 70 pruned nodes, max_depth=12
# [11]#011train-auc:0.81031#011validation-auc:0.692568
# [17:37:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 812 extra nodes, 70 pruned nodes, max_depth=12
# [12]#011train-auc:0.816661#011validation-auc:0.694694
# [17:37:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 566 extra nodes, 44 pruned nodes, max_depth=12
# [13]#011train-auc:0.818634#011validation-auc:0.69553
# [17:37:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 794 extra nodes, 56 pruned nodes, max_depth=12
# [14]#011train-auc:0.824664#011validation-auc:0.696989
# [17:37:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 798 extra nodes, 92 pruned nodes, max_depth=12
# [15]#011train-auc:0.82953#011validation-auc:0.698863
# [17:37:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 530 extra nodes, 48 pruned nodes, max_depth=12
# [16]#011train-auc:0.832258#011validation-auc:0.699837
# [17:37:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 612 extra nodes, 58 pruned nodes, max_depth=12
# [17]#011train-auc:0.835093#011validation-auc:0.700665
# [17:37:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 310 extra nodes, 26 pruned nodes, max_depth=12
# [18]#011train-auc:0.836514#011validation-auc:0.701395
# [17:37:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 532 extra nodes, 46 pruned nodes, max_depth=12
# [19]#011train-auc:0.839602#011validation-auc:0.701806
# [17:37:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 490 extra nodes, 40 pruned nodes, max_depth=12
# [20]#011train-auc:0.841533#011validation-auc:0.702507
# [17:37:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 506 extra nodes, 34 pruned nodes, max_depth=12
# [21]#011train-auc:0.844228#011validation-auc:0.703155
# [17:37:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 474 extra nodes, 56 pruned nodes, max_depth=12
# [22]#011train-auc:0.84693#011validation-auc:0.70399
# [17:37:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 628 extra nodes, 56 pruned nodes, max_depth=12
# [23]#011train-auc:0.850013#011validation-auc:0.704809
# [17:37:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 618 extra nodes, 66 pruned nodes, max_depth=12
# [24]#011train-auc:0.853337#011validation-auc:0.705432
# [17:37:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 386 extra nodes, 44 pruned nodes, max_depth=12
# [25]#011train-auc:0.855173#011validation-auc:0.706116
# [17:37:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 312 extra nodes, 40 pruned nodes, max_depth=12
# [26]#011train-auc:0.856403#011validation-auc:0.706592
# [17:37:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 544 extra nodes, 46 pruned nodes, max_depth=12
# [27]#011train-auc:0.859472#011validation-auc:0.70744
# [17:37:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 316 extra nodes, 40 pruned nodes, max_depth=12
# [28]#011train-auc:0.860976#011validation-auc:0.707932
# [17:37:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 448 extra nodes, 48 pruned nodes, max_depth=12
# [29]#011train-auc:0.862669#011validation-auc:0.707934
# [17:37:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 402 extra nodes, 60 pruned nodes, max_depth=12
# [30]#011train-auc:0.864721#011validation-auc:0.708633
# [17:37:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 544 extra nodes, 36 pruned nodes, max_depth=12
# [31]#011train-auc:0.867005#011validation-auc:0.709054
# [17:37:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 260 extra nodes, 30 pruned nodes, max_depth=12
# [32]#011train-auc:0.868344#011validation-auc:0.709141
# [17:37:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 384 extra nodes, 30 pruned nodes, max_depth=12
# [33]#011train-auc:0.870179#011validation-auc:0.709317
# [17:37:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 224 extra nodes, 32 pruned nodes, max_depth=12
# [34]#011train-auc:0.870905#011validation-auc:0.70972
# [17:37:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 468 extra nodes, 66 pruned nodes, max_depth=12
# [35]#011train-auc:0.873223#011validation-auc:0.710198
# [17:37:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 334 extra nodes, 32 pruned nodes, max_depth=12
# [36]#011train-auc:0.874815#011validation-auc:0.710341
# [17:37:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 642 extra nodes, 56 pruned nodes, max_depth=12
# [37]#011train-auc:0.87823#011validation-auc:0.710626
# [17:37:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 486 extra nodes, 56 pruned nodes, max_depth=12
# [38]#011train-auc:0.88019#011validation-auc:0.711154
# [17:37:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 480 extra nodes, 42 pruned nodes, max_depth=12
# [39]#011train-auc:0.882995#011validation-auc:0.711323
# [17:37:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 474 extra nodes, 50 pruned nodes, max_depth=12
# [40]#011train-auc:0.885529#011validation-auc:0.711703
# [17:37:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 364 extra nodes, 44 pruned nodes, max_depth=12
# [41]#011train-auc:0.887084#011validation-auc:0.711936
# [17:37:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 360 extra nodes, 38 pruned nodes, max_depth=12
# [42]#011train-auc:0.888569#011validation-auc:0.711951
# [17:37:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 490 extra nodes, 42 pruned nodes, max_depth=12
# [43]#011train-auc:0.890456#011validation-auc:0.712353
# [17:37:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 770 extra nodes, 94 pruned nodes, max_depth=12
# [44]#011train-auc:0.893925#011validation-auc:0.712657
# [17:37:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 322 extra nodes, 46 pruned nodes, max_depth=12
# [45]#011train-auc:0.895123#011validation-auc:0.71293
# [17:37:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 700 extra nodes, 86 pruned nodes, max_depth=12
# [46]#011train-auc:0.898407#011validation-auc:0.713636
# [17:37:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 512 extra nodes, 54 pruned nodes, max_depth=12
# [47]#011train-auc:0.900386#011validation-auc:0.714005
# [17:37:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 272 extra nodes, 44 pruned nodes, max_depth=12
# [48]#011train-auc:0.901494#011validation-auc:0.713963
# [17:37:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 548 extra nodes, 46 pruned nodes, max_depth=12
# [49]#011train-auc:0.90393#011validation-auc:0.714167
# [17:37:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 248 extra nodes, 30 pruned nodes, max_depth=12
# [50]#011train-auc:0.904486#011validation-auc:0.714103
# [17:37:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 634 extra nodes, 58 pruned nodes, max_depth=12
# [51]#011train-auc:0.907129#011validation-auc:0.714076
# [17:37:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 434 extra nodes, 42 pruned nodes, max_depth=12
# [52]#011train-auc:0.908489#011validation-auc:0.714584
# [17:37:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 338 extra nodes, 34 pruned nodes, max_depth=12
# [53]#011train-auc:0.909395#011validation-auc:0.714815
# [17:37:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 406 extra nodes, 68 pruned nodes, max_depth=12
# [54]#011train-auc:0.910484#011validation-auc:0.714802
# [17:37:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 406 extra nodes, 54 pruned nodes, max_depth=12
# [55]#011train-auc:0.912002#011validation-auc:0.71538
# [17:37:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 480 extra nodes, 42 pruned nodes, max_depth=12
# [56]#011train-auc:0.913426#011validation-auc:0.715697
# [17:37:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 314 extra nodes, 40 pruned nodes, max_depth=12
# [57]#011train-auc:0.914259#011validation-auc:0.715653
# [17:37:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 838 extra nodes, 98 pruned nodes, max_depth=12
# [58]#011train-auc:0.917613#011validation-auc:0.716068
# [17:37:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 422 extra nodes, 46 pruned nodes, max_depth=12
# [59]#011train-auc:0.918925#011validation-auc:0.716404
# [17:37:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 292 extra nodes, 34 pruned nodes, max_depth=12
# [60]#011train-auc:0.919634#011validation-auc:0.716617
# [17:37:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 760 extra nodes, 86 pruned nodes, max_depth=12
# [61]#011train-auc:0.922356#011validation-auc:0.716976
# [17:37:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 508 extra nodes, 58 pruned nodes, max_depth=12
# [62]#011train-auc:0.923932#011validation-auc:0.716933
# [17:37:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 498 extra nodes, 46 pruned nodes, max_depth=12
# [63]#011train-auc:0.925402#011validation-auc:0.717454
# [17:37:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 254 extra nodes, 36 pruned nodes, max_depth=12
# [64]#011train-auc:0.925749#011validation-auc:0.71751
# [17:37:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 204 extra nodes, 20 pruned nodes, max_depth=12
# [65]#011train-auc:0.92624#011validation-auc:0.717559
# [17:37:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 736 extra nodes, 86 pruned nodes, max_depth=12
# [66]#011train-auc:0.928567#011validation-auc:0.717542
# [17:37:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 326 extra nodes, 30 pruned nodes, max_depth=12
# [67]#011train-auc:0.929476#011validation-auc:0.717641
# [68]#011train-auc:0.930806#011validation-auc:0.717698
# [17:37:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 478 extra nodes, 52 pruned nodes, max_depth=12
# [17:37:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 678 extra nodes, 56 pruned nodes, max_depth=12
# [69]#011train-auc:0.933103#011validation-auc:0.717975
# [17:37:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 290 extra nodes, 44 pruned nodes, max_depth=12
# [70]#011train-auc:0.933956#011validation-auc:0.718039
# [17:37:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 548 extra nodes, 80 pruned nodes, max_depth=12
# [71]#011train-auc:0.935462#011validation-auc:0.718474
# [17:37:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 552 extra nodes, 60 pruned nodes, max_depth=12
# [72]#011train-auc:0.937018#011validation-auc:0.718688
# [17:37:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 562 extra nodes, 84 pruned nodes, max_depth=12
# [73]#011train-auc:0.938373#011validation-auc:0.718855
# [17:37:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 702 extra nodes, 82 pruned nodes, max_depth=12
# [74]#011train-auc:0.940313#011validation-auc:0.718988
# [17:37:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 372 extra nodes, 54 pruned nodes, max_depth=12
# [75]#011train-auc:0.941059#011validation-auc:0.719111
# [17:37:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 392 extra nodes, 54 pruned nodes, max_depth=12
# [76]#011train-auc:0.941887#011validation-auc:0.719179
# [17:37:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 394 extra nodes, 50 pruned nodes, max_depth=12
# [77]#011train-auc:0.942826#011validation-auc:0.719499
# [17:37:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 712 extra nodes, 100 pruned nodes, max_depth=12
# [78]#011train-auc:0.944573#011validation-auc:0.720078
# [17:37:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 476 extra nodes, 72 pruned nodes, max_depth=12
# [79]#011train-auc:0.945423#011validation-auc:0.720239
# [17:37:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 254 extra nodes, 48 pruned nodes, max_depth=12
# [80]#011train-auc:0.945916#011validation-auc:0.720378
# [17:37:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 498 extra nodes, 46 pruned nodes, max_depth=12
# [81]#011train-auc:0.947015#011validation-auc:0.720352
# [17:37:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 780 extra nodes, 96 pruned nodes, max_depth=12
# [82]#011train-auc:0.949368#011validation-auc:0.720918
# [17:37:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 452 extra nodes, 64 pruned nodes, max_depth=12
# [83]#011train-auc:0.950316#011validation-auc:0.7209
# [17:37:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 368 extra nodes, 48 pruned nodes, max_depth=12
# [84]#011train-auc:0.950873#011validation-auc:0.720959
# [17:37:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 588 extra nodes, 80 pruned nodes, max_depth=12
# [85]#011train-auc:0.952071#011validation-auc:0.721193
# [17:37:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 352 extra nodes, 60 pruned nodes, max_depth=12
# [86]#011train-auc:0.952625#011validation-auc:0.721118
# [17:37:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 640 extra nodes, 86 pruned nodes, max_depth=12
# [87]#011train-auc:0.953878#011validation-auc:0.721273
# [17:37:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 320 extra nodes, 44 pruned nodes, max_depth=12
# [88]#011train-auc:0.954362#011validation-auc:0.721655
# [17:37:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 432 extra nodes, 64 pruned nodes, max_depth=12
# [89]#011train-auc:0.955275#011validation-auc:0.7217
# [17:37:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 444 extra nodes, 44 pruned nodes, max_depth=12
# [90]#011train-auc:0.956063#011validation-auc:0.721911
# [17:37:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 414 extra nodes, 46 pruned nodes, max_depth=12
# [91]#011train-auc:0.956787#011validation-auc:0.722026
# [17:37:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 490 extra nodes, 60 pruned nodes, max_depth=12
# [92]#011train-auc:0.957668#011validation-auc:0.722029
# [17:37:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 360 extra nodes, 52 pruned nodes, max_depth=12
# [93]#011train-auc:0.95824#011validation-auc:0.72228
# [17:37:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 700 extra nodes, 100 pruned nodes, max_depth=12
# [94]#011train-auc:0.959415#011validation-auc:0.722022
# [17:37:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 226 extra nodes, 34 pruned nodes, max_depth=12
# [95]#011train-auc:0.959775#011validation-auc:0.722182
# [17:37:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 600 extra nodes, 90 pruned nodes, max_depth=12
# [96]#011train-auc:0.960806#011validation-auc:0.722545
# [17:37:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 600 extra nodes, 88 pruned nodes, max_depth=12
# [97]#011train-auc:0.961766#011validation-auc:0.722725
# [17:37:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 456 extra nodes, 110 pruned nodes, max_depth=12
# [98]#011train-auc:0.962391#011validation-auc:0.722759
# [17:37:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 458 extra nodes, 70 pruned nodes, max_depth=12
# [99]#011train-auc:0.963064#011validation-auc:0.722955
# [17:37:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 508 extra nodes, 62 pruned nodes, max_depth=12
# [100]#011train-auc:0.963912#011validation-auc:0.723222
# [17:37:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 586 extra nodes, 72 pruned nodes, max_depth=12
# [101]#011train-auc:0.964805#011validation-auc:0.723237
# [17:37:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 584 extra nodes, 82 pruned nodes, max_depth=12
# [102]#011train-auc:0.965657#011validation-auc:0.72324
# [17:37:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 408 extra nodes, 82 pruned nodes, max_depth=12
# [103]#011train-auc:0.966058#011validation-auc:0.723329
# [17:37:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 404 extra nodes, 48 pruned nodes, max_depth=12
# [104]#011train-auc:0.966509#011validation-auc:0.723105
# [17:37:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 424 extra nodes, 78 pruned nodes, max_depth=12
# [105]#011train-auc:0.966995#011validation-auc:0.722933
# [17:37:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 462 extra nodes, 58 pruned nodes, max_depth=12
# [106]#011train-auc:0.967644#011validation-auc:0.723213
# [17:37:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 302 extra nodes, 56 pruned nodes, max_depth=12
# [107]#011train-auc:0.967935#011validation-auc:0.72333
# [17:37:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 842 extra nodes, 132 pruned nodes, max_depth=12
# [108]#011train-auc:0.969233#011validation-auc:0.723467
# [17:37:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 652 extra nodes, 130 pruned nodes, max_depth=12
# [109]#011train-auc:0.970099#011validation-auc:0.723978
# [17:37:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 446 extra nodes, 100 pruned nodes, max_depth=12
# [110]#011train-auc:0.970606#011validation-auc:0.724114
# [17:37:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 392 extra nodes, 74 pruned nodes, max_depth=12
# [111]#011train-auc:0.970992#011validation-auc:0.723912
# [17:37:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 462 extra nodes, 82 pruned nodes, max_depth=12
# [112]#011train-auc:0.971576#011validation-auc:0.724053
# [17:37:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 550 extra nodes, 88 pruned nodes, max_depth=12
# [113]#011train-auc:0.972097#011validation-auc:0.724206
# [17:37:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 538 extra nodes, 82 pruned nodes, max_depth=12
# [114]#011train-auc:0.972884#011validation-auc:0.724476
# [17:37:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 368 extra nodes, 68 pruned nodes, max_depth=12
# [115]#011train-auc:0.973173#011validation-auc:0.724746
# [17:37:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 454 extra nodes, 62 pruned nodes, max_depth=12
# [116]#011train-auc:0.973685#011validation-auc:0.724669
# [17:37:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 296 extra nodes, 62 pruned nodes, max_depth=12
# [117]#011train-auc:0.973811#011validation-auc:0.724669
# [17:37:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 342 extra nodes, 94 pruned nodes, max_depth=12
# [118]#011train-auc:0.974205#011validation-auc:0.724553
# [17:37:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 592 extra nodes, 126 pruned nodes, max_depth=12
# [119]#011train-auc:0.974775#011validation-auc:0.724717
# [17:37:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 334 extra nodes, 94 pruned nodes, max_depth=12
# [120]#011train-auc:0.975026#011validation-auc:0.724797
# [17:37:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 448 extra nodes, 100 pruned nodes, max_depth=12
# [121]#011train-auc:0.97552#011validation-auc:0.724851
# [17:37:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 448 extra nodes, 98 pruned nodes, max_depth=12
# [122]#011train-auc:0.975899#011validation-auc:0.725086
# [17:37:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 274 extra nodes, 64 pruned nodes, max_depth=12
# [123]#011train-auc:0.976043#011validation-auc:0.725011
# [17:37:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 506 extra nodes, 84 pruned nodes, max_depth=12
# [124]#011train-auc:0.976477#011validation-auc:0.725221
# [17:37:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 514 extra nodes, 88 pruned nodes, max_depth=12
# [125]#011train-auc:0.976945#011validation-auc:0.725381
# [17:37:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 458 extra nodes, 84 pruned nodes, max_depth=12
# [126]#011train-auc:0.977449#011validation-auc:0.725493
# [17:37:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 568 extra nodes, 108 pruned nodes, max_depth=12
# [127]#011train-auc:0.978033#011validation-auc:0.725994
# [17:37:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 504 extra nodes, 98 pruned nodes, max_depth=12
# [128]#011train-auc:0.978423#011validation-auc:0.726369
# [17:37:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 614 extra nodes, 98 pruned nodes, max_depth=12
# [129]#011train-auc:0.979088#011validation-auc:0.726573
# [17:37:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 356 extra nodes, 92 pruned nodes, max_depth=12
# [130]#011train-auc:0.979408#011validation-auc:0.72654
# [17:37:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 304 extra nodes, 64 pruned nodes, max_depth=12
# [131]#011train-auc:0.979621#011validation-auc:0.726848
# [17:37:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 316 extra nodes, 52 pruned nodes, max_depth=12
# [132]#011train-auc:0.97986#011validation-auc:0.726781
# [17:37:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 592 extra nodes, 122 pruned nodes, max_depth=12
# [133]#011train-auc:0.980432#011validation-auc:0.726776
# [17:37:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 558 extra nodes, 92 pruned nodes, max_depth=12
# [134]#011train-auc:0.980867#011validation-auc:0.727068
# [17:37:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 412 extra nodes, 92 pruned nodes, max_depth=12
# [135]#011train-auc:0.9812#011validation-auc:0.727271
# [17:37:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 256 extra nodes, 70 pruned nodes, max_depth=12
# [136]#011train-auc:0.981371#011validation-auc:0.727353
# [17:37:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 660 extra nodes, 118 pruned nodes, max_depth=12
# [137]#011train-auc:0.981898#011validation-auc:0.727633
# [17:37:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 714 extra nodes, 90 pruned nodes, max_depth=12
# [138]#011train-auc:0.982396#011validation-auc:0.728138
# [17:37:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 602 extra nodes, 132 pruned nodes, max_depth=12
# [139]#011train-auc:0.982861#011validation-auc:0.728106
# [17:37:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 552 extra nodes, 118 pruned nodes, max_depth=12
# [140]#011train-auc:0.983322#011validation-auc:0.728332
# [17:37:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 328 extra nodes, 84 pruned nodes, max_depth=12
# [141]#011train-auc:0.983549#011validation-auc:0.728398
# [17:37:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 452 extra nodes, 100 pruned nodes, max_depth=12
# [142]#011train-auc:0.983837#011validation-auc:0.728538
# [17:37:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 344 extra nodes, 86 pruned nodes, max_depth=12
# [143]#011train-auc:0.984057#011validation-auc:0.728602
# [17:37:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 278 extra nodes, 88 pruned nodes, max_depth=12
# [144]#011train-auc:0.984142#011validation-auc:0.728743
# [17:37:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 378 extra nodes, 72 pruned nodes, max_depth=12
# [145]#011train-auc:0.984366#011validation-auc:0.728916
# [17:37:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 768 extra nodes, 166 pruned nodes, max_depth=12
# [146]#011train-auc:0.984943#011validation-auc:0.728923
# [17:37:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 404 extra nodes, 92 pruned nodes, max_depth=12
# [147]#011train-auc:0.985086#011validation-auc:0.72895
# [17:37:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 304 extra nodes, 86 pruned nodes, max_depth=12
# [148]#011train-auc:0.985228#011validation-auc:0.729097
# [17:38:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 330 extra nodes, 88 pruned nodes, max_depth=12
# [149]#011train-auc:0.985431#011validation-auc:0.729238
# [17:38:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 362 extra nodes, 100 pruned nodes, max_depth=12
# [150]#011train-auc:0.985583#011validation-auc:0.729279
# [17:38:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 370 extra nodes, 70 pruned nodes, max_depth=12
# [151]#011train-auc:0.985733#011validation-auc:0.729307
# [17:38:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 814 extra nodes, 198 pruned nodes, max_depth=12
# [152]#011train-auc:0.986263#011validation-auc:0.729558
# [17:38:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 444 extra nodes, 102 pruned nodes, max_depth=12
# [153]#011train-auc:0.986574#011validation-auc:0.729658
# [17:38:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 246 extra nodes, 76 pruned nodes, max_depth=12
# [154]#011train-auc:0.986688#011validation-auc:0.729688
# [17:38:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 544 extra nodes, 132 pruned nodes, max_depth=12
# [155]#011train-auc:0.987054#011validation-auc:0.729719
# [17:38:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 574 extra nodes, 112 pruned nodes, max_depth=12
# [156]#011train-auc:0.987394#011validation-auc:0.729897
# [17:38:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 328 extra nodes, 88 pruned nodes, max_depth=12
# [157]#011train-auc:0.987569#011validation-auc:0.730068
# [17:38:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 212 extra nodes, 56 pruned nodes, max_depth=12
# [158]#011train-auc:0.987659#011validation-auc:0.730039
# [17:38:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 568 extra nodes, 142 pruned nodes, max_depth=12
# [159]#011train-auc:0.98793#011validation-auc:0.730156
# [17:38:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 268 extra nodes, 56 pruned nodes, max_depth=12
# [160]#011train-auc:0.98805#011validation-auc:0.730129
# [17:38:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 334 extra nodes, 102 pruned nodes, max_depth=12
# [161]#011train-auc:0.988198#011validation-auc:0.730213
# [17:38:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 612 extra nodes, 116 pruned nodes, max_depth=12
# [162]#011train-auc:0.988594#011validation-auc:0.730188
# [17:38:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 390 extra nodes, 98 pruned nodes, max_depth=12
# [163]#011train-auc:0.988718#011validation-auc:0.730356
# [17:38:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 270 extra nodes, 66 pruned nodes, max_depth=12
# [164]#011train-auc:0.988902#011validation-auc:0.730408
# [17:38:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 488 extra nodes, 118 pruned nodes, max_depth=12
# [165]#011train-auc:0.989119#011validation-auc:0.730552
# [17:38:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 316 extra nodes, 94 pruned nodes, max_depth=12
# [166]#011train-auc:0.989222#011validation-auc:0.730518
# [17:38:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 310 extra nodes, 124 pruned nodes, max_depth=12
# [167]#011train-auc:0.989354#011validation-auc:0.730498
# [17:38:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 244 extra nodes, 74 pruned nodes, max_depth=12
# [168]#011train-auc:0.989437#011validation-auc:0.730525
# [17:38:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 478 extra nodes, 100 pruned nodes, max_depth=12
# [169]#011train-auc:0.989676#011validation-auc:0.730395
# [17:38:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 568 extra nodes, 152 pruned nodes, max_depth=12
# [170]#011train-auc:0.989958#011validation-auc:0.730616
# [17:38:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 224 extra nodes, 40 pruned nodes, max_depth=12
# [171]#011train-auc:0.99#011validation-auc:0.730652
# [17:38:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 336 extra nodes, 94 pruned nodes, max_depth=12
# [172]#011train-auc:0.990152#011validation-auc:0.730744
# [17:38:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 632 extra nodes, 160 pruned nodes, max_depth=12
# [173]#011train-auc:0.990459#011validation-auc:0.730881
# [17:38:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 320 extra nodes, 78 pruned nodes, max_depth=12
# [174]#011train-auc:0.99058#011validation-auc:0.730958
# [17:38:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 478 extra nodes, 134 pruned nodes, max_depth=12
# [175]#011train-auc:0.990748#011validation-auc:0.730783
# [17:38:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 526 extra nodes, 122 pruned nodes, max_depth=12
# [176]#011train-auc:0.990951#011validation-auc:0.730806
# [17:38:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 464 extra nodes, 118 pruned nodes, max_depth=12
# [177]#011train-auc:0.991138#011validation-auc:0.730793
# [17:38:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 300 extra nodes, 78 pruned nodes, max_depth=12
# [178]#011train-auc:0.991217#011validation-auc:0.730828
# [17:38:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 280 extra nodes, 112 pruned nodes, max_depth=12
# [179]#011train-auc:0.991295#011validation-auc:0.731023
# [17:38:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 506 extra nodes, 130 pruned nodes, max_depth=12
# [180]#011train-auc:0.991491#011validation-auc:0.731087
# [17:38:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 802 extra nodes, 194 pruned nodes, max_depth=12
# [181]#011train-auc:0.991892#011validation-auc:0.731169
# [17:38:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 442 extra nodes, 118 pruned nodes, max_depth=12
# [182]#011train-auc:0.992047#011validation-auc:0.731261
# [17:38:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 692 extra nodes, 164 pruned nodes, max_depth=12
# [183]#011train-auc:0.992385#011validation-auc:0.7315
# [17:38:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 424 extra nodes, 88 pruned nodes, max_depth=12
# [184]#011train-auc:0.992569#011validation-auc:0.731614
# [17:38:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 384 extra nodes, 130 pruned nodes, max_depth=12
# [185]#011train-auc:0.992661#011validation-auc:0.731466
# [17:38:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 370 extra nodes, 120 pruned nodes, max_depth=12
# [186]#011train-auc:0.992736#011validation-auc:0.731605
# [17:38:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 334 extra nodes, 106 pruned nodes, max_depth=12
# [187]#011train-auc:0.992821#011validation-auc:0.731645
# [17:38:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 420 extra nodes, 110 pruned nodes, max_depth=12
# [188]#011train-auc:0.99295#011validation-auc:0.731729
# [17:38:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 550 extra nodes, 172 pruned nodes, max_depth=12
# [189]#011train-auc:0.993155#011validation-auc:0.731984
# [17:38:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 376 extra nodes, 142 pruned nodes, max_depth=12
# [190]#011train-auc:0.993241#011validation-auc:0.732025
# [17:38:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 448 extra nodes, 116 pruned nodes, max_depth=12
# [191]#011train-auc:0.99339#011validation-auc:0.732156
# [17:38:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 794 extra nodes, 182 pruned nodes, max_depth=12
# [192]#011train-auc:0.993689#011validation-auc:0.732283
# [17:38:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 366 extra nodes, 86 pruned nodes, max_depth=12
# [193]#011train-auc:0.993769#011validation-auc:0.73228
# [17:38:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 436 extra nodes, 130 pruned nodes, max_depth=12
# [194]#011train-auc:0.993889#011validation-auc:0.732393
# [17:38:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 696 extra nodes, 176 pruned nodes, max_depth=12
# [195]#011train-auc:0.994124#011validation-auc:0.732523
# [17:38:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 200 extra nodes, 78 pruned nodes, max_depth=12
# [196]#011train-auc:0.994143#011validation-auc:0.732502
# [17:38:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 184 extra nodes, 60 pruned nodes, max_depth=12
# [197]#011train-auc:0.994202#011validation-auc:0.732424
# [17:38:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 382 extra nodes, 104 pruned nodes, max_depth=12
# [198]#011train-auc:0.994318#011validation-auc:0.732498
# [17:38:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 606 extra nodes, 166 pruned nodes, max_depth=12
# [199]#011train-auc:0.994508#011validation-auc:0.732659
# [17:38:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 416 extra nodes, 146 pruned nodes, max_depth=12
# [200]#011train-auc:0.994584#011validation-auc:0.732869
# [17:38:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 626 extra nodes, 166 pruned nodes, max_depth=12
# [201]#011train-auc:0.994796#011validation-auc:0.733037
# [17:38:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 580 extra nodes, 142 pruned nodes, max_depth=12
# [202]#011train-auc:0.994933#011validation-auc:0.733075
# [17:38:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 532 extra nodes, 214 pruned nodes, max_depth=12
# [203]#011train-auc:0.995053#011validation-auc:0.732985
# [17:38:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 394 extra nodes, 118 pruned nodes, max_depth=12
# [204]#011train-auc:0.995166#011validation-auc:0.733154
# [17:38:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 256 extra nodes, 70 pruned nodes, max_depth=12
# [205]#011train-auc:0.995197#011validation-auc:0.733069
# [17:38:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 414 extra nodes, 144 pruned nodes, max_depth=12
# [206]#011train-auc:0.995275#011validation-auc:0.73295
# [17:38:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 324 extra nodes, 132 pruned nodes, max_depth=12
# [207]#011train-auc:0.99533#011validation-auc:0.732956
# [17:38:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 700 extra nodes, 248 pruned nodes, max_depth=12
# [208]#011train-auc:0.995494#011validation-auc:0.733302
# [17:38:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 398 extra nodes, 110 pruned nodes, max_depth=12
# [209]#011train-auc:0.99557#011validation-auc:0.733275
# [17:38:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 218 extra nodes, 72 pruned nodes, max_depth=12
# [210]#011train-auc:0.995581#011validation-auc:0.733307
# [17:38:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 450 extra nodes, 120 pruned nodes, max_depth=12
# [211]#011train-auc:0.995697#011validation-auc:0.733302
# [17:38:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 374 extra nodes, 132 pruned nodes, max_depth=12
# [212]#011train-auc:0.995741#011validation-auc:0.733297
# [17:38:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 316 extra nodes, 122 pruned nodes, max_depth=12
# [213]#011train-auc:0.995804#011validation-auc:0.733219
# [17:38:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 406 extra nodes, 128 pruned nodes, max_depth=12
# [214]#011train-auc:0.995871#011validation-auc:0.733262
# [17:38:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 420 extra nodes, 168 pruned nodes, max_depth=12
# [215]#011train-auc:0.99597#011validation-auc:0.733388
# [17:38:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 330 extra nodes, 140 pruned nodes, max_depth=12
# [216]#011train-auc:0.996024#011validation-auc:0.733437
# [17:38:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 260 extra nodes, 92 pruned nodes, max_depth=12
# [217]#011train-auc:0.996053#011validation-auc:0.733405
# [17:38:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 500 extra nodes, 164 pruned nodes, max_depth=12
# [218]#011train-auc:0.996129#011validation-auc:0.733616
# [17:38:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 346 extra nodes, 150 pruned nodes, max_depth=12
# [219]#011train-auc:0.996185#011validation-auc:0.733711
# [17:38:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 278 extra nodes, 104 pruned nodes, max_depth=12
# [220]#011train-auc:0.996252#011validation-auc:0.733743
# [17:38:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 284 extra nodes, 104 pruned nodes, max_depth=12
# [221]#011train-auc:0.996294#011validation-auc:0.733721
# [17:38:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 392 extra nodes, 122 pruned nodes, max_depth=12
# [222]#011train-auc:0.996361#011validation-auc:0.733834
# [17:38:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 210 extra nodes, 82 pruned nodes, max_depth=12
# [223]#011train-auc:0.99638#011validation-auc:0.73387
# [17:38:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 350 extra nodes, 136 pruned nodes, max_depth=12
# [224]#011train-auc:0.996424#011validation-auc:0.733954
# [17:38:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 298 extra nodes, 128 pruned nodes, max_depth=12
# [225]#011train-auc:0.996466#011validation-auc:0.734044
# [17:38:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 676 extra nodes, 246 pruned nodes, max_depth=12
# [226]#011train-auc:0.996642#011validation-auc:0.734146
# [17:38:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 350 extra nodes, 154 pruned nodes, max_depth=12
# [227]#011train-auc:0.9967#011validation-auc:0.734156
# [17:38:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 438 extra nodes, 126 pruned nodes, max_depth=12
# [228]#011train-auc:0.996756#011validation-auc:0.734287
# [17:38:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 482 extra nodes, 162 pruned nodes, max_depth=12
# [229]#011train-auc:0.996857#011validation-auc:0.734405
# [17:38:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 296 extra nodes, 130 pruned nodes, max_depth=12
# [230]#011train-auc:0.996886#011validation-auc:0.734459
# [17:38:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 260 extra nodes, 96 pruned nodes, max_depth=12
# [231]#011train-auc:0.996933#011validation-auc:0.734537
# [17:38:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 530 extra nodes, 184 pruned nodes, max_depth=12
# [232]#011train-auc:0.997018#011validation-auc:0.734779
# [17:38:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 480 extra nodes, 168 pruned nodes, max_depth=12
# [233]#011train-auc:0.997097#011validation-auc:0.734817
# [17:38:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 436 extra nodes, 128 pruned nodes, max_depth=12
# [234]#011train-auc:0.99717#011validation-auc:0.734806
# [17:38:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 384 extra nodes, 174 pruned nodes, max_depth=12
# [235]#011train-auc:0.997211#011validation-auc:0.734899
# [17:38:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 340 extra nodes, 162 pruned nodes, max_depth=12
# [236]#011train-auc:0.99724#011validation-auc:0.734965
# [17:38:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 364 extra nodes, 174 pruned nodes, max_depth=12
# [237]#011train-auc:0.997281#011validation-auc:0.735007
# [17:38:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 226 extra nodes, 144 pruned nodes, max_depth=12
# [238]#011train-auc:0.997306#011validation-auc:0.734931
# [17:38:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 476 extra nodes, 128 pruned nodes, max_depth=12
# [239]#011train-auc:0.997386#011validation-auc:0.735056
# [17:38:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 338 extra nodes, 168 pruned nodes, max_depth=12
# [240]#011train-auc:0.997416#011validation-auc:0.735149
# [17:38:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 444 extra nodes, 184 pruned nodes, max_depth=12
# [241]#011train-auc:0.997467#011validation-auc:0.735211
# [17:38:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 246 extra nodes, 110 pruned nodes, max_depth=12
# [242]#011train-auc:0.997482#011validation-auc:0.735164
# [17:38:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 548 extra nodes, 198 pruned nodes, max_depth=12
# [243]#011train-auc:0.997568#011validation-auc:0.735232
# [17:38:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 396 extra nodes, 152 pruned nodes, max_depth=12
# [244]#011train-auc:0.997634#011validation-auc:0.735284
# [17:38:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 298 extra nodes, 114 pruned nodes, max_depth=12
# [245]#011train-auc:0.997665#011validation-auc:0.735347
# [17:38:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 480 extra nodes, 220 pruned nodes, max_depth=12
# [246]#011train-auc:0.997714#011validation-auc:0.735313
# [17:38:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 460 extra nodes, 176 pruned nodes, max_depth=12
# [247]#011train-auc:0.997775#011validation-auc:0.735282
# [17:38:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 372 extra nodes, 166 pruned nodes, max_depth=12
# [248]#011train-auc:0.99783#011validation-auc:0.735292
# [17:38:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 292 extra nodes, 118 pruned nodes, max_depth=12
# [249]#011train-auc:0.997859#011validation-auc:0.7353
# [17:38:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 490 extra nodes, 186 pruned nodes, max_depth=12
# [250]#011train-auc:0.997916#011validation-auc:0.735314
# [17:38:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 368 extra nodes, 168 pruned nodes, max_depth=12
# [251]#011train-auc:0.997947#011validation-auc:0.735264
# [17:38:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 242 extra nodes, 112 pruned nodes, max_depth=12
# [252]#011train-auc:0.997962#011validation-auc:0.735293
# [17:38:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 202 extra nodes, 160 pruned nodes, max_depth=12
# [253]#011train-auc:0.997968#011validation-auc:0.735352
# [17:38:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 256 extra nodes, 124 pruned nodes, max_depth=12
# [254]#011train-auc:0.997993#011validation-auc:0.735313
# [17:38:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 420 extra nodes, 240 pruned nodes, max_depth=12
# [255]#011train-auc:0.998032#011validation-auc:0.735146
# [17:38:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 372 extra nodes, 168 pruned nodes, max_depth=12
# [256]#011train-auc:0.998067#011validation-auc:0.735176
# [17:38:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 250 extra nodes, 148 pruned nodes, max_depth=12
# [257]#011train-auc:0.998075#011validation-auc:0.735187
# [17:38:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 312 extra nodes, 178 pruned nodes, max_depth=12
# [258]#011train-auc:0.998095#011validation-auc:0.735232
# [17:38:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 424 extra nodes, 174 pruned nodes, max_depth=12
# [259]#011train-auc:0.998137#011validation-auc:0.735318
# [17:38:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 304 extra nodes, 164 pruned nodes, max_depth=12
# [260]#011train-auc:0.998158#011validation-auc:0.735352
# [17:38:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 392 extra nodes, 172 pruned nodes, max_depth=12
# [261]#011train-auc:0.998192#011validation-auc:0.73542
# [17:38:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 514 extra nodes, 194 pruned nodes, max_depth=12
# [262]#011train-auc:0.998269#011validation-auc:0.735492
# [17:38:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 278 extra nodes, 178 pruned nodes, max_depth=12
# [263]#011train-auc:0.998281#011validation-auc:0.735525
# [17:38:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 448 extra nodes, 206 pruned nodes, max_depth=12
# [264]#011train-auc:0.99831#011validation-auc:0.735657
# [17:38:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 316 extra nodes, 186 pruned nodes, max_depth=12
# [265]#011train-auc:0.998325#011validation-auc:0.735732
# [17:38:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 276 extra nodes, 214 pruned nodes, max_depth=12
# [266]#011train-auc:0.998341#011validation-auc:0.735661
# [17:38:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 210 extra nodes, 106 pruned nodes, max_depth=12
# [267]#011train-auc:0.998348#011validation-auc:0.735657
# [17:38:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 342 extra nodes, 118 pruned nodes, max_depth=12
# [268]#011train-auc:0.998384#011validation-auc:0.735693
# [17:38:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 384 extra nodes, 162 pruned nodes, max_depth=12
# [269]#011train-auc:0.998415#011validation-auc:0.735707
# [17:38:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 496 extra nodes, 168 pruned nodes, max_depth=12
# [270]#011train-auc:0.998473#011validation-auc:0.735538
# [17:38:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 426 extra nodes, 214 pruned nodes, max_depth=12
# [271]#011train-auc:0.998491#011validation-auc:0.735681
# [17:38:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 394 extra nodes, 186 pruned nodes, max_depth=12
# [272]#011train-auc:0.998533#011validation-auc:0.735521
# [17:38:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 254 extra nodes, 118 pruned nodes, max_depth=12
# [273]#011train-auc:0.998557#011validation-auc:0.7355
# [17:38:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 404 extra nodes, 186 pruned nodes, max_depth=12
# [274]#011train-auc:0.998593#011validation-auc:0.735474
# [17:38:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 426 extra nodes, 244 pruned nodes, max_depth=12
# [275]#011train-auc:0.998632#011validation-auc:0.735485
# Stopping. Best iteration:
# [265]#011train-auc:0.998325#011validation-auc:0.735732
# Parameter image will be renamed to image_uri in SageMaker Python SDK v2.
# Training seconds: 129
# Billable seconds: 129
# ................................Arguments: serve
# [2022-01-07 17:48:38 +0000] [1] [INFO] Starting gunicorn 19.9.0
# [2022-01-07 17:48:38 +0000] [1] [INFO] Listening at: http://0.0.0.0:8080 (1)
# [2022-01-07 17:48:38 +0000] [1] [INFO] Using worker: gevent
# [2022-01-07 17:48:38 +0000] [21] [INFO] Booting worker with pid: 21
# [2022-01-07 17:48:38 +0000] [22] [INFO] Booting worker with pid: 22
# [2022-01-07 17:48:38 +0000] [23] [INFO] Booting worker with pid: 23
# /opt/amazon/lib/python3.7/site-packages/gunicorn/workers/ggevent.py:65: MonkeyPatchWarning: Monkey-patching ssl after ssl has already been imported may lead to errors, including RecursionError on Python 3.6. It may also silently lead to incorrect behaviour on Python 3.7. Please monkey-patch earlier. See https://github.com/gevent/gevent/issues/1016. Modules that had direct imports (NOT patched): ['urllib3.util.ssl_ (/opt/amazon/lib/python3.7/site-packages/urllib3/util/ssl_.py)', 'urllib3.util (/opt/amazon/lib/python3.7/site-packages/urllib3/util/__init__.py)'].
#   monkey.patch_all(subprocess=True)
# /opt/amazon/lib/python3.7/site-packages/gunicorn/workers/ggevent.py:65: MonkeyPatchWarning: Monkey-patching ssl after ssl has already been imported may lead to errors, including RecursionError on Python 3.6. It may also silently lead to incorrect behaviour on Python 3.7. Please monkey-patch earlier. See https://github.com/gevent/gevent/issues/1016. Modules that had direct imports (NOT patched): ['urllib3.util.ssl_ (/opt/amazon/lib/python3.7/site-packages/urllib3/util/ssl_.py)', 'urllib3.util (/opt/amazon/lib/python3.7/site-packages/urllib3/util/__init__.py)'].
#   monkey.patch_all(subprocess=True)
# [2022-01-07 17:48:38 +0000] [24] [INFO] Booting worker with pid: 24
# [2022-01-07:17:48:38:INFO] Model loaded successfully for worker : 21
# [2022-01-07:17:48:38:INFO] Model loaded successfully for worker : 22
# /opt/amazon/lib/python3.7/site-packages/gunicorn/workers/ggevent.py:65: MonkeyPatchWarning: Monkey-patching ssl after ssl has already been imported may lead to errors, including RecursionError on Python 3.6. It may also silently lead to incorrect behaviour on Python 3.7. Please monkey-patch earlier. See https://github.com/gevent/gevent/issues/1016. Modules that had direct imports (NOT patched): ['urllib3.util.ssl_ (/opt/amazon/lib/python3.7/site-packages/urllib3/util/ssl_.py)', 'urllib3.util (/opt/amazon/lib/python3.7/site-packages/urllib3/util/__init__.py)'].
#   monkey.patch_all(subprocess=True)
# /opt/amazon/lib/python3.7/site-packages/gunicorn/workers/ggevent.py:65: MonkeyPatchWarning: Monkey-patching ssl after ssl has already been imported may lead to errors, including RecursionError on Python 3.6. It may also silently lead to incorrect behaviour on Python 3.7. Please monkey-patch earlier. See https://github.com/gevent/gevent/issues/1016. Modules that had direct imports (NOT patched): ['urllib3.util.ssl_ (/opt/amazon/lib/python3.7/site-packages/urllib3/util/ssl_.py)', 'urllib3.util (/opt/amazon/lib/python3.7/site-packages/urllib3/util/__init__.py)'].
#   monkey.patch_all(subprocess=True)
# [2022-01-07:17:48:38:INFO] Model loaded successfully for worker : 23
# [2022-01-07:17:48:38:INFO] Model loaded successfully for worker : 24
# [2022-01-07:17:48:42:INFO] Sniff delimiter as ','
# [2022-01-07:17:48:42:INFO] Determined delimiter of CSV input is ','
# [2022-01-07:17:48:42:INFO] Sniff delimiter as ','
# [2022-01-07:17:48:42:INFO] Determined delimiter of CSV input is ','
#
# 2022-01-07T17:48:42.041:[sagemaker logs]: MaxConcurrentTransforms=4, MaxPayloadInMB=6, BatchStrategy=MULTI_RECORD

# %%
## Download tranform output from s3 location ##
# !aws s3 cp --recursive $xgb_transformer.output_path $data_dir/xgb_results
# Out:
# download: s3://sagemaker-us-east-1-345989147144/xgboost-220107-1704-019-09793d10-2022-01-07-17-43-25-064/X_test.csv.out to data/xgb/xgb_results/X_test.csv.out

# %%
## Calculate test accuracy and auc performance ##
output = pd.read_csv(os.path.join(data_dir, 'xgb_results/X_test.csv.out'), header=None)
predictions = [round(num) for num in output.squeeze().values]
probs = [p for p in output.squeeze().values]

from sklearn.metrics import accuracy_score, roc_auc_score
print ('XBG test accuracy: {}'.format(accuracy_score(y_test, predictions)))
print ('XBG test auc: {}'.format(roc_auc_score(y_test, probs)))
# Out:
# XBG test accuracy: 0.6754911162173534
# XBG test auc: 0.737488341310636
