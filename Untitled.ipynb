# %%
import os
import boto3
import re
import sagemaker
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import io
import time
import json
import sagemaker.amazon.common as smac
import scipy
from sklearn.model_selection import train_test_split
from sagemaker.amazon.amazon_estimator import get_image_uri

role = sagemaker.get_execution_role()
region = boto3.Session().region_name
session = sagemaker.Session()
bucket = session.default_bucket()

prefix = (
    "sagemaker/readmissions" 
)

# %%
# !pip install sagemaker==1.72.0
# Out:
# Requirement already satisfied: sagemaker==1.72.0 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (1.72.0)
# Requirement already satisfied: scipy>=0.19.0 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from sagemaker==1.72.0) (1.5.3)
# Requirement already satisfied: importlib-metadata>=1.4.0 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from sagemaker==1.72.0) (3.6.0)
# Requirement already satisfied: numpy>=1.9.0 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from sagemaker==1.72.0) (1.19.5)
# Requirement already satisfied: boto3>=1.14.12 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from sagemaker==1.72.0) (1.20.25)
# Requirement already satisfied: smdebug-rulesconfig==0.1.4 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from sagemaker==1.72.0) (0.1.4)
# Requirement already satisfied: protobuf>=3.1 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from sagemaker==1.72.0) (3.15.1)
# Requirement already satisfied: protobuf3-to-dict>=0.1.5 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from sagemaker==1.72.0) (0.1.5)
# Requirement already satisfied: packaging>=20.0 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from sagemaker==1.72.0) (21.3)
# Requirement already satisfied: botocore<1.24.0,>=1.23.25 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from boto3>=1.14.12->sagemaker==1.72.0) (1.23.25)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from boto3>=1.14.12->sagemaker==1.72.0) (0.10.0)
# Requirement already satisfied: s3transfer<0.6.0,>=0.5.0 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from boto3>=1.14.12->sagemaker==1.72.0) (0.5.0)
# Requirement already satisfied: zipp>=0.5 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from importlib-metadata>=1.4.0->sagemaker==1.72.0) (3.4.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from importlib-metadata>=1.4.0->sagemaker==1.72.0) (4.0.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from packaging>=20.0->sagemaker==1.72.0) (2.4.7)
# Requirement already satisfied: six>=1.9 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from protobuf>=3.1->sagemaker==1.72.0) (1.15.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from botocore<1.24.0,>=1.23.25->boto3>=1.14.12->sagemaker==1.72.0) (2.8.1)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from botocore<1.24.0,>=1.23.25->boto3>=1.14.12->sagemaker==1.72.0) (1.26.7)

# %%
X_sparse = scipy.sparse.load_npz('./readmissions_X.npz')
y_sparse = scipy.sparse.load_npz('./readmissions_y.npz')

# %%
X = pd.DataFrame(np.array(X_sparse.todense()))
y = pd.DataFrame(np.array(y_sparse.todense()).reshape(-1,1))

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, y, test_size=0.33)

X_train, X_val, Y_train, Y_val = train_test_split(X_train, Y_train, test_size=0.33)

# %%
data_dir = './data/'
if not os.path.exists(data_dir):
    os.makedirs(data_dir)

# %%
pd.DataFrame(X_test).to_csv(os.path.join(data_dir, 'test.csv'), header=False, index=False)

pd.concat([Y_val, X_val], axis=1).to_csv(os.path.join(data_dir, 'validation.csv'), header=False, index=False)
pd.concat([Y_train, X_train], axis=1).to_csv(os.path.join(data_dir, 'train.csv'), header=False, index=False)

# %%
prefix = 'readmission-xgboost'

test_location = session.upload_data(os.path.join(data_dir, 'test.csv'), key_prefix=prefix)
val_location = session.upload_data(os.path.join(data_dir, 'validation.csv'), key_prefix=prefix)
train_location = session.upload_data(os.path.join(data_dir, 'train.csv'), key_prefix=prefix)

# %%
container = get_image_uri(session.boto_region_name, 'xgboost')

# First we create a SageMaker estimator object for our model.
xgb = sagemaker.estimator.Estimator(container, # The location of the container we wish to use
                                    role,                                    # What is our current IAM Role
                                    train_instance_count=1,                  # How many compute instances
                                    train_instance_type='ml.m4.xlarge',      # What kind of compute instances
                                    output_path='s3://{}/{}/output'.format(session.default_bucket(), prefix),
                                    sagemaker_session=session)

# And then set the algorithm specific parameters.
xgb.set_hyperparameters(max_depth=5,
                        eta=0.2,
                        gamma=4,
                        min_child_weight=6,
                        subsample=0.8,
                        silent=0,
                        objective='binary:logistic',
                        early_stopping_rounds=10,
                        num_round=500)
# Out:
# 'get_image_uri' method will be deprecated in favor of 'ImageURIProvider' class in SageMaker Python SDK v2.
# There is a more up to date SageMaker XGBoost image. To use the newer image, please set 'repo_version'='1.0-1'. For example:
# 	get_image_uri(region, 'xgboost', '1.0-1').
# Parameter image_name will be renamed to image_uri in SageMaker Python SDK v2.

# %%
s3_input_train = sagemaker.s3_input(s3_data=train_location, content_type='csv')
s3_input_validation = sagemaker.s3_input(s3_data=val_location, content_type='csv')
# Out:
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.

# %%
xgb.fit({'train': s3_input_train, 'validation': s3_input_validation})
# Out:
# 2021-12-28 16:44:13 Starting - Starting the training job...
# 2021-12-28 16:44:15 Starting - Launching requested ML instances......
# 2021-12-28 16:45:23 Starting - Preparing the instances for training.........
# 2021-12-28 16:46:51 Downloading - Downloading input data...
# 2021-12-28 16:47:34 Training - Downloading the training image..Arguments: train
# [2021-12-28:16:47:57:INFO] Running standalone xgboost training.
# [2021-12-28:16:47:57:INFO] File size need to be processed in the node: 12.79mb. Available memory size in the node: 8384.88mb
# [2021-12-28:16:47:57:INFO] Determined delimiter of CSV input is ','
# [16:47:57] S3DistributionType set as FullyReplicated
# [16:47:57] 42031x105 matrix with 4413255 entries loaded from /opt/ml/input/data/train?format=csv&label_column=0&delimiter=,
# [2021-12-28:16:47:57:INFO] Determined delimiter of CSV input is ','
# [16:47:57] S3DistributionType set as FullyReplicated
# [16:47:57] 20702x105 matrix with 2173710 entries loaded from /opt/ml/input/data/validation?format=csv&label_column=0&delimiter=,
# [16:47:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 4 pruned nodes, max_depth=5
# [0]#011train-error:0.381242#011validation-error:0.386774
# Multiple eval metrics have been passed: 'validation-error' will be used for early stopping.
# Will train until validation-error hasn't improved in 10 rounds.
# [16:47:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 4 pruned nodes, max_depth=5
# [1]#011train-error:0.37941#011validation-error:0.386243
# [16:47:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 6 pruned nodes, max_depth=5
# [2]#011train-error:0.376341#011validation-error:0.38262
# [3]#011train-error:0.377317#011validation-error:0.383876
# [16:47:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 0 pruned nodes, max_depth=5
# [16:47:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 4 pruned nodes, max_depth=5
# [4]#011train-error:0.375937#011validation-error:0.381895
# [16:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 12 pruned nodes, max_depth=5
# [5]#011train-error:0.375057#011validation-error:0.380157
# [16:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 6 pruned nodes, max_depth=5
# [6]#011train-error:0.374676#011validation-error:0.380929
# [16:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 2 pruned nodes, max_depth=5
# [7]#011train-error:0.374081#011validation-error:0.380446
# [16:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 6 pruned nodes, max_depth=5
# [8]#011train-error:0.371987#011validation-error:0.381268
# [16:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 12 pruned nodes, max_depth=5
# [9]#011train-error:0.371583#011validation-error:0.38064
# [16:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 8 pruned nodes, max_depth=5
# [10]#011train-error:0.370298#011validation-error:0.378273
# [16:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 8 pruned nodes, max_depth=5
# [11]#011train-error:0.369442#011validation-error:0.378418
# [16:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 2 pruned nodes, max_depth=5
# [12]#011train-error:0.366896#011validation-error:0.377162
# [16:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 4 pruned nodes, max_depth=5
# [13]#011train-error:0.366016#011validation-error:0.376582
# [16:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 8 pruned nodes, max_depth=5
# [14]#011train-error:0.364088#011validation-error:0.375857
# [16:47:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 10 pruned nodes, max_depth=5
# [15]#011train-error:0.362708#011validation-error:0.374698
# [16:47:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 6 pruned nodes, max_depth=5
# [16]#011train-error:0.362471#011validation-error:0.37407
# [16:47:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 12 pruned nodes, max_depth=5
# [17]#011train-error:0.361709#011validation-error:0.373539
# [16:47:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 10 pruned nodes, max_depth=5
# [18]#011train-error:0.36071#011validation-error:0.373635
# [16:47:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 4 pruned nodes, max_depth=5
# [19]#011train-error:0.359616#011validation-error:0.372573
# [16:47:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 10 pruned nodes, max_depth=5
# [20]#011train-error:0.358378#011validation-error:0.372379
# [16:47:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 4 pruned nodes, max_depth=5
# [21]#011train-error:0.357998#011validation-error:0.373201
# [16:47:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 4 pruned nodes, max_depth=5
# [22]#011train-error:0.356784#011validation-error:0.373394
# [16:47:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 12 pruned nodes, max_depth=5
# [23]#011train-error:0.355999#011validation-error:0.373007
# [16:48:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 22 pruned nodes, max_depth=5
# [24]#011train-error:0.355523#011validation-error:0.372814
# [16:48:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 12 pruned nodes, max_depth=5
# [25]#011train-error:0.355357#011validation-error:0.372379
# [16:48:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 8 pruned nodes, max_depth=5
# [26]#011train-error:0.355333#011validation-error:0.372428
# [16:48:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 8 pruned nodes, max_depth=5
# [27]#011train-error:0.354928#011validation-error:0.3718
# [16:48:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 12 pruned nodes, max_depth=5
# [28]#011train-error:0.354358#011validation-error:0.371993
# [16:48:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 4 pruned nodes, max_depth=5
# [29]#011train-error:0.353549#011validation-error:0.371317
# [16:48:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 10 pruned nodes, max_depth=5
# [30]#011train-error:0.35343#011validation-error:0.371172
# [16:48:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 6 pruned nodes, max_depth=5
# [31]#011train-error:0.353477#011validation-error:0.370882
# [16:48:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 12 pruned nodes, max_depth=5
# [32]#011train-error:0.352002#011validation-error:0.369674
# [16:48:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 10 pruned nodes, max_depth=5
# [33]#011train-error:0.351122#011validation-error:0.370206
# [16:48:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 2 pruned nodes, max_depth=5
# [34]#011train-error:0.350622#011validation-error:0.36953
#
# 2021-12-28 16:48:12 Uploading - Uploading generated training model
# 2021-12-28 16:48:12 Completed - Training job completed
# [16:48:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 8 pruned nodes, max_depth=5
# [35]#011train-error:0.350313#011validation-error:0.369095
# [16:48:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 10 pruned nodes, max_depth=5
# [36]#011train-error:0.349789#011validation-error:0.369578
# [16:48:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 2 pruned nodes, max_depth=5
# [37]#011train-error:0.349409#011validation-error:0.370157
# [16:48:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 10 pruned nodes, max_depth=5
# [38]#011train-error:0.34967#011validation-error:0.370206
# [16:48:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 6 pruned nodes, max_depth=5
# [39]#011train-error:0.348005#011validation-error:0.369143
# [16:48:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 12 pruned nodes, max_depth=5
# [40]#011train-error:0.347672#011validation-error:0.368322
# [16:48:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 8 pruned nodes, max_depth=5
# [41]#011train-error:0.346125#011validation-error:0.367984
# [16:48:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 4 pruned nodes, max_depth=5
# [42]#011train-error:0.345079#011validation-error:0.367694
# [16:48:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 4 pruned nodes, max_depth=5
# [43]#011train-error:0.345031#011validation-error:0.367066
# [16:48:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 8 pruned nodes, max_depth=5
# [44]#011train-error:0.344341#011validation-error:0.366728
# [16:48:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 12 pruned nodes, max_depth=5
# [45]#011train-error:0.343485#011validation-error:0.367597
# [16:48:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 2 pruned nodes, max_depth=5
# [46]#011train-error:0.343627#011validation-error:0.367935
# [16:48:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 4 pruned nodes, max_depth=5
# [47]#011train-error:0.343746#011validation-error:0.368322
# [16:48:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 20 pruned nodes, max_depth=5
# [48]#011train-error:0.34327#011validation-error:0.367887
# [16:48:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 8 pruned nodes, max_depth=5
# [49]#011train-error:0.342009#011validation-error:0.367018
# [16:48:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 12 pruned nodes, max_depth=5
# [50]#011train-error:0.3417#011validation-error:0.366583
# [16:48:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 12 pruned nodes, max_depth=5
# [51]#011train-error:0.341272#011validation-error:0.365713
# [16:48:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 4 pruned nodes, max_depth=5
# [52]#011train-error:0.341153#011validation-error:0.365327
# [16:48:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 8 pruned nodes, max_depth=5
# [53]#011train-error:0.340392#011validation-error:0.365762
# [16:48:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 2 pruned nodes, max_depth=5
# [54]#011train-error:0.339725#011validation-error:0.365569
# [16:48:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 14 pruned nodes, max_depth=5
# [55]#011train-error:0.339273#011validation-error:0.365134
# [16:48:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 12 pruned nodes, max_depth=5
# [56]#011train-error:0.339273#011validation-error:0.364844
# [16:48:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 6 pruned nodes, max_depth=5
# [57]#011train-error:0.339226#011validation-error:0.364941
# [16:48:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 14 pruned nodes, max_depth=5
# [58]#011train-error:0.338988#011validation-error:0.365327
# [16:48:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 6 pruned nodes, max_depth=5
# [59]#011train-error:0.338869#011validation-error:0.365472
# [16:48:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 18 pruned nodes, max_depth=5
# [60]#011train-error:0.33875#011validation-error:0.365375
# [16:48:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 6 pruned nodes, max_depth=5
# [61]#011train-error:0.338583#011validation-error:0.36552
# [16:48:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 12 pruned nodes, max_depth=5
# [62]#011train-error:0.338274#011validation-error:0.365762
# [16:48:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 24 pruned nodes, max_depth=5
# [63]#011train-error:0.337893#011validation-error:0.366293
# [16:48:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 6 pruned nodes, max_depth=5
# [64]#011train-error:0.337275#011validation-error:0.366728
# [16:48:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 16 pruned nodes, max_depth=5
# [65]#011train-error:0.337227#011validation-error:0.366438
# [16:48:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 12 pruned nodes, max_depth=5
# [66]#011train-error:0.337108#011validation-error:0.366486
# Stopping. Best iteration:
# [56]#011train-error:0.339273#011validation-error:0.364844
# Training seconds: 81
# Billable seconds: 81

# %%
xgb_transformer = xgb.transformer(instance_count = 1, instance_type = 'ml.m4.xlarge')
xgb_transformer.transform(test_location, content_type='text/csv', split_type='Line')
# Out:
# Parameter image will be renamed to image_uri in SageMaker Python SDK v2.

# %%
xgb_transformer.wait()
# Out:
# ...................................Arguments: serve
# [2021-12-28 16:54:11 +0000] [1] [INFO] Starting gunicorn 19.9.0
# [2021-12-28 16:54:11 +0000] [1] [INFO] Listening at: http://0.0.0.0:8080 (1)
# [2021-12-28 16:54:11 +0000] [1] [INFO] Using worker: gevent
# [2021-12-28 16:54:11 +0000] [22] [INFO] Booting worker with pid: 22
# [2021-12-28 16:54:11 +0000] [23] [INFO] Booting worker with pid: 23
# [2021-12-28 16:54:11 +0000] [24] [INFO] Booting worker with pid: 24
# [2021-12-28 16:54:11 +0000] [25] [INFO] Booting worker with pid: 25
# /opt/amazon/lib/python3.7/site-packages/gunicorn/workers/ggevent.py:65: MonkeyPatchWarning: Monkey-patching ssl after ssl has already been imported may lead to errors, including RecursionError on Python 3.6. It may also silently lead to incorrect behaviour on Python 3.7. Please monkey-patch earlier. See https://github.com/gevent/gevent/issues/1016. Modules that had direct imports (NOT patched): ['urllib3.util.ssl_ (/opt/amazon/lib/python3.7/site-packages/urllib3/util/ssl_.py)', 'urllib3.util (/opt/amazon/lib/python3.7/site-packages/urllib3/util/__init__.py)'].
#   monkey.patch_all(subprocess=True)
# [2021-12-28:16:54:11:INFO] Model loaded successfully for worker : 22
# /opt/amazon/lib/python3.7/site-packages/gunicorn/workers/ggevent.py:65: MonkeyPatchWarning: Monkey-patching ssl after ssl has already been imported may lead to errors, including RecursionError on Python 3.6. It may also silently lead to incorrect behaviour on Python 3.7. Please monkey-patch earlier. See https://github.com/gevent/gevent/issues/1016. Modules that had direct imports (NOT patched): ['urllib3.util.ssl_ (/opt/amazon/lib/python3.7/site-packages/urllib3/util/ssl_.py)', 'urllib3.util (/opt/amazon/lib/python3.7/site-packages/urllib3/util/__init__.py)'].
#   monkey.patch_all(subprocess=True)
# /opt/amazon/lib/python3.7/site-packages/gunicorn/workers/ggevent.py:65: MonkeyPatchWarning: Monkey-patching ssl after ssl has already been imported may lead to errors, including RecursionError on Python 3.6. It may also silently lead to incorrect behaviour on Python 3.7. Please monkey-patch earlier. See https://github.com/gevent/gevent/issues/1016. Modules that had direct imports (NOT patched): ['urllib3.util.ssl_ (/opt/amazon/lib/python3.7/site-packages/urllib3/util/ssl_.py)', 'urllib3.util (/opt/amazon/lib/python3.7/site-packages/urllib3/util/__init__.py)'].
#   monkey.patch_all(subprocess=True)
# [2021-12-28:16:54:11:INFO] Model loaded successfully for worker : 23
# [2021-12-28:16:54:11:INFO] Model loaded successfully for worker : 24
# /opt/amazon/lib/python3.7/site-packages/gunicorn/workers/ggevent.py:65: MonkeyPatchWarning: Monkey-patching ssl after ssl has already been imported may lead to errors, including RecursionError on Python 3.6. It may also silently lead to incorrect behaviour on Python 3.7. Please monkey-patch earlier. See https://github.com/gevent/gevent/issues/1016. Modules that had direct imports (NOT patched): ['urllib3.util.ssl_ (/opt/amazon/lib/python3.7/site-packages/urllib3/util/ssl_.py)', 'urllib3.util (/opt/amazon/lib/python3.7/site-packages/urllib3/util/__init__.py)'].
#   monkey.patch_all(subprocess=True)
# [2021-12-28:16:54:11:INFO] Model loaded successfully for worker : 25
#
# [2021-12-28:16:54:16:INFO] Sniff delimiter as ','
# [2021-12-28:16:54:16:INFO] Determined delimiter of CSV input is ','
# [2021-12-28:16:54:16:INFO] Sniff delimiter as ','
# [2021-12-28:16:54:16:INFO] Determined delimiter of CSV input is ','
# [2021-12-28:16:54:16:INFO] Sniff delimiter as ','
# [2021-12-28:16:54:16:INFO] Determined delimiter of CSV input is ','
# [2021-12-28:16:54:16:INFO] Sniff delimiter as ','
# [2021-12-28:16:54:16:INFO] Determined delimiter of CSV input is ','
# 2021-12-28T16:54:15.692:[sagemaker logs]: MaxConcurrentTransforms=4, MaxPayloadInMB=6, BatchStrategy=MULTI_RECORD

# %%
# !aws s3 cp --recursive $xgb_transformer.output_path $data_dir
# Out:
# download: s3://sagemaker-us-east-1-345989147144/xgboost-2021-12-28-16-48-26-686/test.csv.out to data/test.csv.out

# %%
predictions = pd.read_csv(os.path.join(data_dir, 'test.csv.out'), header=None)
predictions = [round(num) for num in predictions.squeeze().values]

# %%
from sklearn.metrics import accuracy_score
accuracy_score(Y_test, predictions)
# Out:
# 0.6366872714327324

# %%
train_y.values
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-d76bf6027069> in <module>
# ----> 1 train_y.values
#
# NameError: name 'train_y' is not defined

# %%
X_test.values
# Out:
# array([[38,  9, 79, ...,  1,  0,  1],
#        [18,  1, 20, ...,  1,  0,  1],
#        [ 1,  3, 33, ...,  1,  0,  1],
#        ...,
#        [12,  6, 62, ...,  1,  1,  0],
#        [23,  4, 52, ...,  1,  0,  1],
#        [ 9,  3,  1, ...,  0,  0,  1]])

# %%
Y_train.values[:,0]
# Out:
# array([1, 1, 1, ..., 0, 0, 1])

# %%
import io
import numpy as np
import sagemaker.amazon.common as smac

buf = io.BytesIO()
smac.write_numpy_to_dense_tensor(buf, X_train.values.astype("float32"), Y_train.values[:,0].astype("float32"))
buf.seek(0)

key = "recordio-pb-data"
boto3.resource("s3").Bucket(bucket).Object(os.path.join(prefix, "train", key)).upload_fileobj(buf)
s3_train_data = f"s3://{bucket}/{prefix}/train/{key}"
print(f"uploaded training data location: {s3_train_data}")

buf = io.BytesIO()
smac.write_numpy_to_dense_tensor(buf, X_val.values.astype("float32"), Y_val.values[:,0].astype("float32"))
buf.seek(0)

key = "recordio-pb-data"
boto3.resource("s3").Bucket(bucket).Object(os.path.join(prefix, "val", key)).upload_fileobj(buf)
s3_val_data = f"s3://{bucket}/{prefix}/val/{key}"
print(f"uploaded validation data location: {s3_val_data}")
# Out:
# uploaded training data location: s3://sagemaker-us-east-1-345989147144/readmission-xgboost/train/recordio-pb-data
# uploaded validation data location: s3://sagemaker-us-east-1-345989147144/readmission-xgboost/val/recordio-pb-data

# %%
container = get_image_uri(session.boto_region_name, 'linear-learner')
# Out:
# 'get_image_uri' method will be deprecated in favor of 'ImageURIProvider' class in SageMaker Python SDK v2.

# %%
linear = sagemaker.estimator.Estimator(
    container,
    role,
    train_instance_count=1,
    train_instance_type="ml.c4.xlarge",
    output_path='s3://{}/{}/output'.format(session.default_bucket(), prefix),
    sagemaker_session=session)
linear.set_hyperparameters(feature_dim=105, predictor_type="binary_classifier", mini_batch_size=200)

linear.fit({'train': s3_train_data, 'validation': s3_val_data})
# Out:
# Parameter image_name will be renamed to image_uri in SageMaker Python SDK v2.
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# 2021-12-28 17:56:58 Starting - Starting the training job...
# 2021-12-28 17:57:00 Starting - Launching requested ML instances......
# 2021-12-28 17:58:00 Starting - Preparing the instances for training.........
# 2021-12-28 17:59:58 Downloading - Downloading input data...
# 2021-12-28 18:00:27 Training - Downloading the training image...
# 2021-12-28 18:00:49 Training - Training image download completed. Training in progress..Docker entrypoint called with argument(s): train
# Running default environment configuration script
# [12/28/2021 18:00:54 INFO 140167606798144] Reading default configuration from /opt/amazon/lib/python3.7/site-packages/algorithm/resources/default-input.json: {'mini_batch_size': '1000', 'epochs': '15', 'feature_dim': 'auto', 'use_bias': 'true', 'binary_classifier_model_selection_criteria': 'accuracy', 'f_beta': '1.0', 'target_recall': '0.8', 'target_precision': '0.8', 'num_models': 'auto', 'num_calibration_samples': '10000000', 'init_method': 'uniform', 'init_scale': '0.07', 'init_sigma': '0.01', 'init_bias': '0.0', 'optimizer': 'auto', 'loss': 'auto', 'margin': '1.0', 'quantile': '0.5', 'loss_insensitivity': '0.01', 'huber_delta': '1.0', 'num_classes': '1', 'accuracy_top_k': '3', 'wd': 'auto', 'l1': 'auto', 'momentum': 'auto', 'learning_rate': 'auto', 'beta_1': 'auto', 'beta_2': 'auto', 'bias_lr_mult': 'auto', 'bias_wd_mult': 'auto', 'use_lr_scheduler': 'true', 'lr_scheduler_step': 'auto', 'lr_scheduler_factor': 'auto', 'lr_scheduler_minimum_lr': 'auto', 'positive_example_weight_mult': '1.0', 'balance_multiclass_weights': 'false', 'normalize_data': 'true', 'normalize_label': 'auto', 'unbias_data': 'auto', 'unbias_label': 'auto', 'num_point_for_scaler': '10000', '_kvstore': 'auto', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_log_level': 'info', '_tuning_objective_metric': '', 'early_stopping_patience': '3', 'early_stopping_tolerance': '0.001', '_enable_profiler': 'false'}
# [12/28/2021 18:00:54 INFO 140167606798144] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {'feature_dim': '105', 'predictor_type': 'binary_classifier', 'mini_batch_size': '200'}
# [12/28/2021 18:00:54 INFO 140167606798144] Final configuration: {'mini_batch_size': '200', 'epochs': '15', 'feature_dim': '105', 'use_bias': 'true', 'binary_classifier_model_selection_criteria': 'accuracy', 'f_beta': '1.0', 'target_recall': '0.8', 'target_precision': '0.8', 'num_models': 'auto', 'num_calibration_samples': '10000000', 'init_method': 'uniform', 'init_scale': '0.07', 'init_sigma': '0.01', 'init_bias': '0.0', 'optimizer': 'auto', 'loss': 'auto', 'margin': '1.0', 'quantile': '0.5', 'loss_insensitivity': '0.01', 'huber_delta': '1.0', 'num_classes': '1', 'accuracy_top_k': '3', 'wd': 'auto', 'l1': 'auto', 'momentum': 'auto', 'learning_rate': 'auto', 'beta_1': 'auto', 'beta_2': 'auto', 'bias_lr_mult': 'auto', 'bias_wd_mult': 'auto', 'use_lr_scheduler': 'true', 'lr_scheduler_step': 'auto', 'lr_scheduler_factor': 'auto', 'lr_scheduler_minimum_lr': 'auto', 'positive_example_weight_mult': '1.0', 'balance_multiclass_weights': 'false', 'normalize_data': 'true', 'normalize_label': 'auto', 'unbias_data': 'auto', 'unbias_label': 'auto', 'num_point_for_scaler': '10000', '_kvstore': 'auto', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_log_level': 'info', '_tuning_objective_metric': '', 'early_stopping_patience': '3', 'early_stopping_tolerance': '0.001', '_enable_profiler': 'false', 'predictor_type': 'binary_classifier'}
# [12/28/2021 18:00:54 WARNING 140167606798144] Loggers have already been setup.
# Process 1 is a worker.
# [12/28/2021 18:00:54 INFO 140167606798144] Using default worker.
# [12/28/2021 18:00:55 INFO 140167606798144] Checkpoint loading and saving are disabled.
# [2021-12-28 18:00:55.236] [tensorio] [warning] TensorIO is already initialized; ignoring the initialization routine.
# [2021-12-28 18:00:55.259] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 0, "duration": 24, "num_examples": 1, "num_bytes": 93600}
# [12/28/2021 18:00:55 INFO 140167606798144] Create Store: local
# [2021-12-28 18:00:55.494] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 1, "duration": 233, "num_examples": 51, "num_bytes": 4773600}
# [12/28/2021 18:00:55 INFO 140167606798144] Scaler algorithm parameters
#  <algorithm.scaler.ScalerAlgorithmStable object at 0x7f7aefd8db50>
# [12/28/2021 18:00:55 INFO 140167606798144] Scaling model computed with parameters:
#  {'stdev_label': None, 'stdev_weight':
# [ 8.090905    2.9950528  19.624228    1.7132819   1.2910368   0.92793983
#   1.2687938   1.9260647   0.42903596  0.14        0.10958592  0.14200126
#   0.49909332  0.49909332  0.19960132  0.29483306  0.3752017   0.4369576
#   0.3727656   0.15432377  0.11716551  0.17589569  0.3187852   0.1175715
#   0.10782532  0.1365938   0.27385622  0.14331861  0.10282063  0.10421049
#   0.18794209  0.19503611  0.15642294  0.148145    0.14397235  0.10870936
#   0.11757153  0.11511286  0.23639373  0.25281954  0.11428089  0.19317421
#   0.17004599  0.1664797   0.11878067  0.21672618  0.24773286  0.12310664
#   0.18328285  0.1298557   0.11675807  0.13762526  0.11174573  0.12801915
#   0.13728234  0.18938574  0.245485    0.1636767   0.25332075  0.18026826
#   0.14814498  0.10558123  0.10914857  0.11511288  0.12272003  0.1462353
#   0.19340809  0.10421048  0.13693853  0.20600818  0.149716    0.46529198
#   0.15341444  0.2277888   0.26036164  0.25348747  0.3577428   0.12539944
#   0.12272003  0.11302081  0.10826831  0.16841061  0.49983507  0.19293995
#   0.27490166  0.37606284  0.21672624  0.11511286  0.11634903  0.3977772
#   0.38451365  0.10235292  0.121943    0.3096858   0.29144642  0.25498176
#   0.23911442  0.3274669   0.49872485  0.45859924  0.31628093  0.49895224
#   0.4989522   0.4207067   0.4207067 ]
# <NDArray 105 @cpu(0)>, 'mean_label': None, 'mean_weight':
# [1
, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 6}, "Metrics": {"validation_binary_classification_cross_entropy_objective": {"sum": 0.734236174649679, "count": 1, "min": 0.734236174649679, "max": 0.734236174649679}}}
# #metrics {"StartTime": 1640714465.9169204, "EndTime": 1640714465.9169366, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 7}, "Metrics": {"validation_binary_classification_cross_entropy_objective": {"sum": 0.7570144499273026, "count": 1, "min": 0.7570144499273026, "max": 0.7570144499273026}}}
# #metrics {"StartTime": 1640714465.9169838, "EndTime": 1640714465.916999, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 8}, "Metrics": {"validation_binary_classification_cross_entropy_objective": {"sum": 0.650090933007303, "count": 1, "min": 0.650090933007303, "max": 0.650090933007303}}}
# #metrics {"StartTime": 1640714465.9170468, "EndTime": 1640714465.9170632, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 9}, "Metrics": {"validation_binary_classification_cross_entropy_objective": {"sum": 0.6505864021478903, "count": 1, "min": 0.6505864021478903, "max": 0.6505864021478903}}}
# #metrics {"StartTime": 1640714465.91711, "EndTime": 1640714465.9171257, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 10}, "Metrics": {"validation_binary_classification_cross_entropy_objective": {"sum": 0.6499678562279658, "count": 1, "min": 0.6499678562279658, "max": 0.6499678562279658}}}
# #metrics {"StartTime": 1640714465.917174, "EndTime": 1640714465.91719, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 11}, "Metrics": {"validation_binary_classification_cross_entropy_objective": {"sum": 0.6506885325502122, "count": 1, "min": 0.6506885325502122, "max": 0.6506885325502122}}}
# #metrics {"StartTime": 1640714465.9172387, "EndTime": 1640714465.9172542, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 12}, "Metrics": {"validation_binary_classification_cross_entropy_objective": {"sum": 0.728408198024487, "count": 1, "min": 0.728408198024487, "max": 0.728408198024487}}}
# #metrics {"StartTime": 1640714465.9173112, "EndTime": 1640714465.9173276, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 13}, "Metrics": {"validation_binary_classification_cross_entropy_objective": {"sum": 0.7488904482569053, "count": 1, "min": 0.7488904482569053, "max": 0.7488904482569053}}}
# #metrics {"StartTime": 1640714465.9173765, "EndTime": 1640714465.9173915, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 14}, "Metrics": {"validation_binary_classification_cross_entropy_objective": {"sum": 0.7285489684981938, "count": 1, "min": 0.7285489684981938, "max": 0.7285489684981938}}}
# #metrics {"StartTime": 1640714465.9174337, "EndTime": 1640714465.9174495, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 15}, "Metrics": {"validation_binary_classification_cross_entropy_objective": {"sum": 0.7486961680948417, "count": 1, "min": 0.7486961680948417, "max": 0.7486961680948417}}}
# #metrics {"StartTime": 1640714465.9174907, "EndTime": 1640714465.9175053, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 16}, "Metrics": {"validation_binary_classification_cross_entropy_objective": {"sum": 0.6703172878486133, "count": 1, "min": 0.6703172878486133, "max": 0.6703172878486133}}}
# #metrics {"StartTime": 1640714465.9175506, "EndTime": 1640714465.9175665, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 17}, "Metrics": {"validation_binary_classification_cross_entropy_objective": {"sum": 0.6706266837147236, "count": 1, "min": 0.6706266837147236, "max": 0.6706266837147236}}}
# #metrics {"StartTime": 1640714465.9176202, "EndTime": 1640714465.917636, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 18}, "Metrics": {"validation_binary_classification_cross_entropy_objective": {"sum": 0.6703320749139293, "count": 1, "min": 0.6703320749139293, "max": 0.6703320749139293}}}
# #metrics {"StartTime": 1640714465.917692, "EndTime": 1640714465.917707, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 19}, "Metrics": {"validation_binary_classification_cross_entropy_objective": {"sum": 0.6706544855644986, "count": 1, "min": 0.6706544855644986, "max": 0.6706544855644986}}}
# #metrics {"StartTime": 1640714465.917742, "EndTime": 1640714465.917756, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 20}, "Metrics": {"validation_binary_classification_cross_entropy_objective": {"sum": 0.6806434537002907, "count": 1, "min": 0.6806434537002907, "max": 0.6806434537002907}}}
# #metrics {"StartTime": 1640714465.917811, "EndTime": 1640714465.9178257, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 21}, "Metrics": {"validation_binary_classification_cross_entropy_objective": {"sum": 0.6877332497030028, "count": 1, "min": 0.6877332497030028, "max": 0.6877332497030028}}}
# #metrics {"StartTime": 1640714465.9178746, "EndTime": 1640714465.9178874, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 22}, "Metrics": {"validation_binary_classification_cross_entropy_objective": {"sum": 0.6810724090555534, "count": 1, "min": 0.6810724090555534, "max": 0.6810724090555534}}}
# #metrics {"StartTime": 1640714465.9179225, "EndTime": 1640714465.9179368, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 23}, "Metrics": {"validation_binary_classification_cross_entropy_objective": {"sum": 0.6883201204789524, "count": 1, "min": 0.6883201204789524, "max": 0.6883201204789524}}}
# #metrics {"StartTime": 1640714465.9179912, "EndTime": 1640714465.9180064, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 24}, "Metrics": {"validation_binary_classification_cross_entropy_objective": {"sum": 0.6927519437023182, "count": 1, "min": 0.6927519437023182, "max": 0.6927519437023182}}}
# #metrics {"StartTime": 1640714465.9180605, "EndTime": 1640714465.9180756, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 25}, "Metrics": {"validation_binary_classification_cross_entropy_objective": {"sum": 0.6925367488571784, "count": 1, "min": 0.6925367488571784, "max": 0.6925367488571784}}}
# #metrics {"StartTime": 1640714465.9181235, "EndTime": 1640714465.9181373, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 26}, "Metrics": {"validation_binary_classification_cross_entropy_objective": {"sum": 0.6926987468994777, "count": 1, "min": 0.6926987468994777, "max": 0.6926987468994777}}}
# #metrics {"StartTime": 1640714465.9181812, "EndTime": 1640714465.9181957, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 27}, "Metrics": {"validation_binary_classification_cross_entropy_objective": {"sum": 0.6927408522977286, "count": 1, "min": 0.6927408522977286, "max": 0.6927408522977286}}}
# #metrics {"StartTime": 1640714465.9182432, "EndTime": 1640714465.9182577, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 28}, "Metrics": {"validation_binary_classification_cross_entropy_objective": {"sum": 0.699673385553781, "count": 1, "min": 0.699673385553781, "max": 0.699673385553781}}}
# #metrics {"StartTime": 1640714465.918304, "EndTime": 1640714465.918319, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 29}, "Metrics": {"validation_binary_classification_cross_entropy_objective": {"sum": 0.6974336091429355, "count": 1, "min": 0.6974336091429355, "max": 0.6974336091429355}}}
# #metrics {"StartTime": 1640714465.9183733, "EndTime": 1640714465.9183896, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 30}, "Metrics": {"validation_binary_classification_cross_entropy_objective": {"sum": 0.7004928474621592, "count": 1, "min": 0.7004928474621592, "max": 0.7004928474621592}}}
# #metrics {"StartTime": 1640714465.9184394, "EndTime": 1640714465.9184546, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 31}, "Metrics": {"validation_binary_classification_cross_entropy_objective": {"sum": 0.6978583562064316, "count": 1, "min": 0.6978583562064316, "max": 0.6978583562064316}}}
# [12/28/2021 18:01:05 INFO 140167606798144] #quality_metric: host=algo-1, epoch=0, validation binary_classification_cross_entropy_objective <loss>=0.6503490724030145
# [12/28/2021 18:01:05 INFO 140167606798144] #early_stopping_criteria_metric: host=algo-1, epoch=0, criteria=sampled_accuracy, value=0.6192638392425871
# [12/28/2021 18:01:05 INFO 140167606798144] Epoch 0: Loss improved. Updating best model
# [12/28/2021 18:01:05 INFO 140167606798144] Saving model for epoch: 0
# [12/28/2021 18:01:05 INFO 140167606798144] Saved checkpoint to "/tmp/tmpmshl40kd/mx-mod-0000.params"
# [12/28/2021 18:01:05 INFO 140167606798144] #progress_metric: host=algo-1, completed 6.666666666666667 % of epochs
# #metrics {"StartTime": 1640714455.628581, "EndTime": 1640714465.9278262, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 52431.0, "count": 1, "min": 52431, "max": 52431}, "Total Batches Seen": {"sum": 263.0, "count": 1, "min": 263, "max": 263}, "Max Records Seen Between Resets": {"sum": 42031.0, "count": 1, "min": 42031, "max": 42031}, "Max Batches Seen Between Resets": {"sum": 211.0, "count": 1, "min": 211, "max": 211}, "Reset Count": {"sum": 3.0, "count": 1, "min": 3, "max": 3}, "Number of Records Since Last Reset": {"sum": 42031.0, "count": 1, "min": 42031, "max": 42031}, "Number of Batches Since Last Reset": {"sum": 211.0, "count": 1, "min": 211, "max": 211}}}
# [12/28/2021 18:01:05 INFO 140167606798144] #throughput_metric: host=algo-1, train throughput=4080.928824027153 records/second
# [2021-12-28 18:01:12.545] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 5, "duration": 6616, "num_examples": 211, "num_bytes": 19670508}
# #metrics {"StartTime": 1640714472.545788, "EndTime": 1640714472.545876, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 0}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6449492625281924, "count": 1, "min": 0.6449492625281924, "max": 0.6449492625281924}}}
# #metrics {"StartTime": 1640714472.5459592, "EndTime": 1640714472.5459812, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 1}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6459116692315965, "count": 1, "min": 0.6459116692315965, "max": 0.6459116692315965}}}
# #metrics {"StartTime": 1640714472.5460353, "EndTime": 1640714472.546053, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 2}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6449852494739351, "count": 1, "min": 0.6449852494739351, "max": 0.6449852494739351}}}
# #metrics {"StartTime": 1640714472.5461104, "EndTime": 1640714472.5461278, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 3}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6459291681562151, "count": 1, "min": 0.6459291681562151, "max": 0.6459291681562151}}}
# #metrics {"StartTime": 1640714472.5461812, "EndTime": 1640714472.5461977, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 4}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.71398215230306, "count": 1, "min": 0.71398215230306, "max": 0.71398215230306}}}
# #metrics {"StartTime": 1640714472.5462365, "EndTime": 1640714472.546245, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 5}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.
, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 25}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6930223192487445, "count": 1, "min": 0.6930223192487445, "max": 0.6930223192487445}}}
# #metrics {"StartTime": 1640714472.5471013, "EndTime": 1640714472.547115, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 26}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6929418658301943, "count": 1, "min": 0.6929418658301943, "max": 0.6929418658301943}}}
# #metrics {"StartTime": 1640714472.5471425, "EndTime": 1640714472.54715, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 27}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.693025014604841, "count": 1, "min": 0.693025014604841, "max": 0.693025014604841}}}
# #metrics {"StartTime": 1640714472.547178, "EndTime": 1640714472.547186, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 28}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6959667892456055, "count": 1, "min": 0.6959667892456055, "max": 0.6959667892456055}}}
# #metrics {"StartTime": 1640714472.5472095, "EndTime": 1640714472.5472162, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 29}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6968493921189081, "count": 1, "min": 0.6968493921189081, "max": 0.6968493921189081}}}
# #metrics {"StartTime": 1640714472.5472434, "EndTime": 1640714472.5472507, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 30}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6959292221069336, "count": 1, "min": 0.6959292221069336, "max": 0.6959292221069336}}}
# #metrics {"StartTime": 1640714472.5472965, "EndTime": 1640714472.5473108, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 31}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6968215299333845, "count": 1, "min": 0.6968215299333845, "max": 0.6968215299333845}}}
# [12/28/2021 18:01:12 INFO 140167606798144] #quality_metric: host=algo-1, epoch=1, train binary_classification_cross_entropy_objective <loss>=0.6449492625281924
# [2021-12-28 18:01:14.851] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/validation", "epoch": 5, "duration": 2286, "num_examples": 104, "num_bytes": 9688536}
# #metrics {"StartTime": 1640714475.2463286, "EndTime": 1640714475.2463884, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 0}, "Metrics": {"validation_binary_classification_cross_entropy_objective": {"sum": 0.6496073092922313, "count": 1, "min": 0.6496073092922313, "max": 0.6496073092922313}}}
# #metrics {"StartTime": 1640714475.246464, "EndTime": 1640714475.2464771, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 1}, "Metrics": {"validation_binary_classification_cross_entropy_objective": {"sum": 0.6509677790038402, "count": 1, "min": 0.6509677790038402, "max": 0.6509677790038402}}}
# #metrics {"StartTime": 1640714475.2465358, "EndTime": 1640714475.2465518, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 2}, "Metrics": {"validation_binary_classification_cross_entropy_objective": {"sum": 0.6496266765002985, "count": 1, "min": 0.6496266765002985, "max": 0.6496266765002985}}}
# #metrics {"StartTime": 1640714475.2466023, "EndTime": 1640714475.246613, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 3}, "Metrics": {"validation_binary_classification_cross_entropy_objective": {"sum": 0.6510300701245653, "count": 1, "min": 0.6510300701245653, "max": 0.6510300701245653}}}
# #metrics {"StartTime": 1640714475.2466598, "EndTime": 1640714475.2466755, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 4}, "Metrics": {"validation_binary_classification_cross_entropy_objective": {"sum": 0.7132014249813244, "count": 1, "min": 0.7132014249813244, "max": 0.7132014249813244}}}
# #metrics {"StartTime": 1640714475.2467215, "EndTime": 1640714475.246737, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 5}, "Metrics": {"validation_binary_classification_cross_entropy_objective": {"sum": 0.7559617184150761, "count": 1, "min": 0.7559617184150761, "max": 0.7559617184150761}}}
# #metrics {"StartTime": 1640714475.2467833, "EndTime": 1640714475.2467983, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 6}, "Metrics": {"validation_binary_classification_cross_entropy_objective": {"sum": 0.7132691685651975, "count": 1, "min": 0.7132691685651975, "max": 0.7132691685651975}}}
# ...
# #metrics {"StartTime": 1640714596.4945037, "EndTime": 1640714596.494521, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 4}, "Metrics": {"validation_binary_classification_cross_entropy_objective": {"sum": 0.6504700739664013, "count": 1, "min": 0.6504700739664013, "max": 0.6504700739664013}}}
# #metrics {"StartTime": 1640714596.4945707, "EndTime": 1640714596.4945812, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 5}, "Metrics": {"validation_binary_classification_cross_entropy_objective": {"sum": 0.7249350829258505, "count": 1, "min": 0.7249350829258505, "max": 0.7249350829258505}}}
# #metrics {"StartTime": 1640714596.494624, "EndTime": 1640714596.4946365, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 6}, "Metrics": {"validation_binary_classification_cross_entropy_objective": {"sum": 0.6504702549166823, "count": 1, "min": 0.6504702549166823, "max": 0.6504702549166823}}}
# #metrics {"StartTime": 1640714596.494684, "EndTime": 1640714596.4946969, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 7}, "Metrics": {"validation_binary_classification_cross_entropy_objective": {"sum": 0.7249376188095221, "count": 1, "min": 0.7249376188095221, "max": 0.7249376188095221}}}
# #metrics {"StartTime": 1640714596.4947405, "EndTime": 1640714596.494755, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 8}, "Metrics": {"validation_binary_classification_cross_entropy_objective": {"sum": 0.6462363209105749, "count": 1, "min": 0.6462363209105749, "max": 0.6462363209105749}}}
# #metrics {"StartTime": 1640714596.494795, "EndTime": 1640714596.494808, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 9}, "Metrics": {"validation_binary_classification_cross_entropy_objective": {"sum": 0.
, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 28}, "Metrics": {"validation_binary_classification_cross_entropy_objective": {"sum": 0.6926886022591888, "count": 1, "min": 0.6926886022591888, "max": 0.6926886022591888}}}
# #metrics {"StartTime": 1640714596.4960237, "EndTime": 1640714596.496038, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 29}, "Metrics": {"validation_binary_classification_cross_entropy_objective": {"sum": 0.6995758286605951, "count": 1, "min": 0.6995758286605951, "max": 0.6995758286605951}}}
# #metrics {"StartTime": 1640714596.496085, "EndTime": 1640714596.4961004, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 30}, "Metrics": {"validation_binary_classification_cross_entropy_objective": {"sum": 0.6927114874945092, "count": 1, "min": 0.6927114874945092, "max": 0.6927114874945092}}}
# #metrics {"StartTime": 1640714596.496141, "EndTime": 1640714596.4961562, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 31}, "Metrics": {"validation_binary_classification_cross_entropy_objective": {"sum": 0.699527684829855, "count": 1, "min": 0.699527684829855, "max": 0.699527684829855}}}
# [12/28/2021 18:03:16 INFO 140167606798144] #quality_metric: host=algo-1, epoch=14, validation binary_classification_cross_entropy_objective <loss>=0.6465096936664907
# [12/28/2021 18:03:16 INFO 140167606798144] #early_stopping_criteria_metric: host=algo-1, epoch=14, criteria=sampled_accuracy, value=0.6253985122210433
# [12/28/2021 18:03:16 INFO 140167606798144] Epoch 14: Loss improved. Updating best model
# [12/28/2021 18:03:16 INFO 140167606798144] Saving model for epoch: 14
# [12/28/2021 18:03:16 INFO 140167606798144] Saved checkpoint to "/tmp/tmpi86ea7ho/mx-mod-0000.params"
# [12/28/2021 18:03:16 INFO 140167606798144] #progress_metric: host=algo-1, completed 100.0 % of epochs
# #metrics {"StartTime": 1640714587.1319032, "EndTime": 1640714596.5027328, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 640865.0, "count": 1, "min": 640865, "max": 640865}, "Total Batches Seen": {"sum": 3217.0, "count": 1, "min": 3217, "max": 3217}, "Max Records Seen Between Resets": {"sum": 42031.0, "count": 1, "min": 42031, "max": 42031}, "Max Batches Seen Between Resets": {"sum": 211.0, "count": 1, "min": 211, "max": 211}, "Reset Count": {"sum": 17.0, "count": 1, "min": 17, "max": 17}, "Number of Records Since Last Reset": {"sum": 42031.0, "count": 1, "min": 42031, "max": 42031}, "Number of Batches Since Last Reset": {"sum": 211.0, "count": 1, "min": 211, "max": 211}}}
# [12/28/2021 18:03:16 INFO 140167606798144] #throughput_metric: host=algo-1, train throughput=4485.244870626874 records/second
# [12/28/2021 18:03:16 WARNING 140167606798144] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [12/28/2021 18:03:16 WARNING 140167606798144] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [2021-12-28 18:03:18.847] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/validation", "epoch": 47, "duration": 2327, "num_examples": 104, "num_bytes": 9688536}
# [12/28/2021 18:03:19 INFO 140167606798144] #early_stopping_criteria_metric: host=algo-1, epoch=14, criteria=sampled_accuracy, value=0.6253985122210433
# [12/28/2021 18:03:19 INFO 140167606798144] Epoch 14: Loss improved. Updating best model
# [2021-12-28 18:03:19.564] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/validation", "epoch": 49, "duration": 325, "num_examples": 104, "num_bytes": 9688536}
# [12/28/2021 18:03:19 INFO 140167606798144] #validation_score (algo-1) : ('binary_classification_cross_entropy_objective', 0.6465172180287816)
# [12/28/2021 18:03:19 INFO 140167606798144] #validation_score (algo-1) : ('binary_classification_accuracy', 0.6253502077094001)
# [12/28/2021 18:03:19 INFO 140167606798144] #validation_score (algo-1) : ('binary_f_1.000', 0.6299971376777025)
# [12/28/2021 18:03:19 INFO 140167606798144] #validation_score (algo-1) : ('precision', 0.6220442769665567)
# [12/28/2021 18:03:19 INFO 140167606798144] #validation_score (algo-1) : ('recall', 0.6381559872426791)
# [12/28/2021 18:03:19 INFO 140167606798144] #validation_score (algo-1) : ('roc_auc_score', 0.6743907416976638)
# [12/28/2021 18:03:19 INFO 140167606798144] #validation_score (algo-1) : ('binary_balanced_accuracy', 0.5)
# [12/28/2021 18:03:19 INFO 140167606798144] #validation_score (algo-1) : ('binary_log_loss', 0.7027240325635856)
# [12/28/2021 18:03:19 INFO 140167606798144] #quality_metric: host=algo-1, validation binary_classification_cross_entropy_objective <loss>=0.6465172180287816
# [12/28/2021 18:03:19 INFO 140167606798144] #quality_metric: host=algo-1, validation binary_classification_accuracy <score>=0.6253502077094001
# [12/28/2021 18:03:19 INFO 140167606798144] #quality_metric: host=algo-1, validation binary_f_1.000 <score>=0.6299971376777025
# [12/28/2021 18:03:19 INFO 140167606798144] #quality_metric: host=algo-1, validation precision <score>=0.6220442769665567
# [12/28/2021 18:03:19 INFO 140167606798144] #quality_metric: host=algo-1, validation recall <score>=0.6381559872426791
# [12/28/2021 18:03:19 INFO 140167606798144] #quality_metric: host=algo-1, validation roc_auc_score <score>=0.6743907416976638
# [12/28/2021 18:03:19 INFO 140167606798144] #quality_metric: host=algo-1, validation binary_balanced_accuracy <score>=0.5
# [12/28/2021 18:03:19 INFO 140167606798144] #quality_metric: host=algo-1, validation binary_log_loss <score>=0.7027240325635856
# [12/28/2021 18:03:19 INFO 140167606798144] Best model found for hyperparameters: {"optimizer": "adam", "learning_rate": 0.005, "wd": 0.0001, "l1": 0.0, "lr_scheduler_step": 10, "lr_scheduler_factor": 0.99, "lr_scheduler_minimum_lr": 0.0001}
# [12/28/2021 18:03:19 INFO 140167606798144] Saved checkpoint to "/tmp/tmpgjgbwu2k/mx-mod-0000.params"
# [12/28/2021 18:03:19 INFO 140167606798144] Test data is not provided.
# #metrics {"StartTime": 1640714455.2346778, "EndTime": 1640714599.6096609, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training"}, "Metrics": {"initialize.time": {"sum": 389.1739845275879, "count": 1, "min": 389.1739845275879, "max": 389.1739845275879}, "epochs": {"sum": 15.0, "count": 1, "min": 15, "max": 15}, "check_early_stopping.time": {"sum": 15.026569366455078, "count": 16, "min": 0.8039474487304688, "max": 1.055002212524414}, "update.time": {"sum": 140820.93477249146, "count": 15, "min": 9163.680076599121, "max": 10293.48635673523}, "finalize.time": {"sum": 3101.5119552612305, "count": 1, "min": 3101.5119552612305, "max": 3101.5119552612305}, "setuptime": {"sum": 24.181127548217773, "count": 1, "min": 24.181127548217773, "max": 24.181127548217773}, "totaltime": {"sum": 144653.60951423645, "count": 1, "min": 144653.60951423645, "max": 144653.60951423645}}}
#
# 2021-12-28 18:03:30 Uploading - Uploading generated training model
# 2021-12-28 18:03:30 Completed - Training job completed
# Training seconds: 212
# Billable seconds: 212

# %%
lr_transformer = linear.transformer(instance_count = 1, instance_type = 'ml.m4.xlarge')
lr_transformer.transform(test_location, content_type='text/csv', split_type='Line')
lr_transformer.wait()
# Out:
# Parameter image will be renamed to image_uri in SageMaker Python SDK v2.
# ..................................Docker entrypoint called with argument(s): serve
# Running default environment configuration script
# [12/28/2021 18:13:56 INFO 139818928498496] loaded entry point class algorithm.serve.server_config:config_api
# [12/28/2021 18:13:56 INFO 139818928498496] loading entry points
# [12/28/2021 18:13:56 INFO 139818928498496] loaded request iterator application/json
# [12/28/2021 18:13:56 INFO 139818928498496] loaded request iterator application/jsonlines
# [12/28/2021 18:13:56 INFO 139818928498496] loaded request iterator application/x-recordio-protobuf
# [12/28/2021 18:13:56 INFO 139818928498496] loaded request iterator text/csv
# [12/28/2021 18:13:56 INFO 139818928498496] loaded response encoder application/json
# [12/28/2021 18:13:56 INFO 139818928498496] loaded response encoder application/jsonlines
# [12/28/2021 18:13:56 INFO 139818928498496] loaded response encoder application/x-recordio-protobuf
# [12/28/2021 18:13:56 INFO 139818928498496] loaded response encoder text/csv
# [12/28/2021 18:13:56 INFO 139818928498496] loaded entry point class algorithm:model
# [12/28/2021 18:13:56 INFO 139818928498496] Number of server workers: 4
# [12/28/2021 18:13:56 INFO 139818928498496] loading model...
# [12/28/2021 18:13:56 INFO 139818928498496] ...model loaded.
# [2021-12-28 18:13:56 +0000] [1] [INFO] Starting gunicorn 20.1.0
# [2021-12-28 18:13:56 +0000] [1] [INFO] Listening at: http://0.0.0.0:8080 (1)
# [2021-12-28 18:13:56 +0000] [1] [INFO] Using worker: sync
# [2021-12-28 18:13:56 +0000] [61] [INFO] Booting worker with pid: 61
# [2021-12-28 18:13:56 +0000] [70] [INFO] Booting worker with pid: 70
# [2021-12-28 18:13:56 +0000] [79] [INFO] Booting worker with pid: 79
# [2021-12-28 18:13:56 +0000] [88] [INFO] Booting worker with pid: 88
# #metrics {"StartTime": 1640715236.5051434, "EndTime": 1640715237.6938996, "Dimensions": {"Algorithm": "LinearLearnerModel", "Host": "UNKNOWN", "Operation": "scoring"}, "Metrics": {"execution_parameters.count": {"sum": 1.0, "count": 1, "min": 1, "max": 1}}}
# #metrics {"StartTime": 1640715236.5051434, "EndTime": 1640715238.500504, "Dimensions": {"Algorithm": "LinearLearnerModel", "Host": "UNKNOWN", "Operation": "scoring"}, "Metrics": {"json.encoder.time": {"sum": 5.5484771728515625, "count": 1, "min": 5.5484771728515625, "max": 5.5484771728515625}, "invocations.count": {"sum": 1.0, "count": 1, "min": 1, "max": 1}}}
# #metrics {"StartTime": 1640715236.5051434, "EndTime": 1640715239.3490932, "Dimensions": {"Algorithm": "LinearLearnerModel", "Host": "UNKNOWN", "Operation": "scoring"}, "Metrics": {"json.encoder.time": {"sum": 63.84873390197754, "count": 1, "min": 63.84873390197754, "max": 63.84873390197754}, "invocations.count": {"sum": 1.0, "count": 1, "min": 1, "max": 1}}}
# #metrics {"StartTime": 1640715236.5051434, "EndTime": 1640715238.500504, "Dimensions": {"Algorithm": "LinearLearnerModel", "Host": "UNKNOWN", "Operation": "scoring"}, "Metrics": {"json.encoder.time": {"sum": 5.5484771728515625, "count": 1, "min": 5.5484771728515625, "max": 5.5484771728515625}, "invocations.count": {"sum": 1.0, "count": 1, "min": 1, "max": 1}}}
# #metrics {"StartTime": 1640715236.5051434, "EndTime": 1640715239.3490932, "Dimensions": {"Algorithm": "LinearLearnerModel", "Host": "UNKNOWN", "Operation": "scoring"}, "Metrics": {"json.encoder.time": {"sum": 63.84873390197754, "count": 1, "min": 63.84873390197754, "max": 63.84873390197754}, "invocations.count": {"sum": 1.0, "count": 1, "min": 1, "max": 1}}}
# 2021-12-28T18:13:57.700:[sagemaker logs]: MaxConcurrentTransforms=4, MaxPayloadInMB=6, BatchStrategy=MULTI_RECORD

# %%
# !aws s3 cp --recursive $lr_transformer.output_path $data_dir
# Out:
# download: s3://sagemaker-us-east-1-345989147144/linear-learner-2021-12-28-18-08-18-047/test.csv.out to data/test.csv.out

# %%
predictions = pd.read_csv(os.path.join(data_dir, 'test.csv.out'), header=None)
predictions = [int(p.split(':')[1]) for p in predictions[0]]

# %%
from sklearn.metrics import accuracy_score
accuracy_score(Y_test, predictions)
# Out:
# 0.6278843975533189
